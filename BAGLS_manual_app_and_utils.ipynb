# %%
# ================= Fold Editor (Contour + Separator) =================
# Classes: BG=0, GLOTTIS=1, RIGHT=2, LEFT=3
# Usage:
#   run_fold_editor(r"path", zoom=200)
#   in the path all data should be placed as pairs "image - mask" with specidic Fehling naming convention (see data set)
# Keys:
#   n = save current as *_mask_corrected.png and go next        (composed: glottis on top, no gaps)
#   m = save current and propagate FOLDS **and separator** to all subsequent frames in the same 100-block
#   p = previous (no save)
#   q = quit
# Mouse:
#   LMB drag + release on LEFT panel  : freehand CLOSED contour (green) → apply polygon correction
#   RMB drag + release on LEFT panel  : separator line (yellow) → reassign fold pixels by side (stores separator)
#   LMB drag + release on RIGHT panel : move folds-complex (RIGHT+LEFT) by translation; separator moves with it; GLOTTIS stays unchanged
# Notes:
#   - Glottis (1) is preserved exactly.
#   - RIGHT panel always shows a COMPOSED view (folds "under" glottis; no gaps).


import os, cv2, numpy as np
from glob import glob
from pathlib import Path

BG, GLOTTIS, RIGHT, LEFT = 0, 1, 2, 3

# ---------- IO ----------
def _read_rgb(p):
    bgr = cv2.imread(p, cv2.IMREAD_COLOR)
    return cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB) if bgr is not None else None

def _read_mask(p):
    m = cv2.imread(p, cv2.IMREAD_UNCHANGED)
    if m is None: return None
    if m.ndim == 3: m = cv2.cvtColor(m, cv2.COLOR_BGR2GRAY)
    return m.astype(np.uint8)

def _save_mask(p, m):
    Path(os.path.dirname(p)).mkdir(parents=True, exist_ok=True)
    cv2.imwrite(p, m.astype(np.uint8))

# ---------- Helpers ----------
def _overlay(rgb, mask):
    out = rgb.copy()
    out[mask==RIGHT]   = (255,  40,  40)
    out[mask==LEFT ]   = ( 40, 180, 255)
    out[mask==GLOTTIS] = (  0,   0,   0)
    return out

def _line_x_of_y(p1, p2, H):
    (y1,x1),(y2,x2) = p1,p2
    y = np.arange(H, dtype=np.float32)
    dy = (y2 - y1); dx = (x2 - x1)
    a = (dx / dy) if abs(dy) > 1e-6 else 0.0
    return x1 + (y - y1) * a

def _midline_from_glottis(mask):
    g = (mask==GLOTTIS).astype(np.uint8)
    ys, xs = np.where(g>0)
    if len(xs) < 10:
        H, W = mask.shape
        return (0, W//2), (H-1, W//2)
    top = (ys.argmin(), xs[ys.argmin()])
    bot = (ys.argmax(), xs[ys.argmax()])
    return (int(top[0]), int(top[1])), (int(bot[0]), int(bot[1]))  # (y,x)

def _apply_polygon_correction(orig_mask, poly_mask, sep_params=None):
    H,W = orig_mask.shape
    newm = orig_mask.copy()
    outside = (~poly_mask)
    rm = ((newm==RIGHT) | (newm==LEFT)) & outside
    newm[rm] = BG

    if sep_params is None:
        p1, p2 = _midline_from_glottis(orig_mask)
        x_line = _line_x_of_y(p1, p2, H)
    else:
        a,b = sep_params
        y = np.arange(H, dtype=np.float32)
        x_line = a*y + b

    xx = np.tile(np.arange(W, dtype=np.float32), (H,1))
    right_side = (xx >= x_line[:,None])

    fill_region = poly_mask & (newm==BG)
    newm[fill_region & right_side]  = LEFT
    newm[fill_region & ~right_side] = RIGHT

    newm[orig_mask==GLOTTIS] = GLOTTIS
    return newm

def _apply_separator(orig_mask, pts_yx):
    H,W = orig_mask.shape
    y1,x1 = pts_yx[0]; y2,x2 = pts_yx[-1]
    dy = (y2 - y1)
    a = (x2 - x1) / dy if abs(dy) > 1e-6 else 0.0
    b = x1 - a*y1

    y = np.arange(H, dtype=np.float32)
    x_line = a*y + b
    xx = np.tile(np.arange(W, dtype=np.float32), (H,1))
    right_side = (xx >= x_line[:,None])

    newm = orig_mask.copy()
    folds = ((newm==RIGHT) | (newm==LEFT))
    newm[folds & right_side]  = LEFT
    newm[folds & ~right_side] = RIGHT
    newm[orig_mask==GLOTTIS] = GLOTTIS
    return newm, (a,b)

# ---------- NEW: “solid underlay” + composition ----------
def _parse_frame_id(rgb_path):
    stem = Path(rgb_path).stem
    try:
        return int(stem.split('_')[0])
    except Exception:
        return None

def _seq_block_end_id(frame_id):
    if frame_id is None: return None
    start = frame_id - ((frame_id - 1) % 100)
    return start + 99

def _translate_folds_only(mask, dy, dx):
    H, W = mask.shape
    cur = mask.copy()
    g = (cur == GLOTTIS)
    r_bin = (cur == RIGHT).astype(np.uint8)
    l_bin = (cur == LEFT ).astype(np.uint8)
    M = np.float32([[1, 0, float(dx)], [0, 1, float(dy)]])
    r_shift = cv2.warpAffine(r_bin, M, (W, H), flags=cv2.INTER_NEAREST, borderMode=cv2.BORDER_CONSTANT, borderValue=0)
    l_shift = cv2.warpAffine(l_bin, M, (W, H), flags=cv2.INTER_NEAREST, borderMode=cv2.BORDER_CONSTANT, borderValue=0)
    out = cur.copy()
    out[(out == RIGHT) | (out == LEFT)] = BG
    out[(r_shift == 1) & (~g)] = RIGHT
    out[(l_shift == 1) & (~g)] = LEFT
    out[g] = GLOTTIS
    return out

def _solid_underlay_from_folds(raw_mask_with_folds, dst_glottis_mask, sep_params=None):
    """
    Build a completely filled folds underlay:
      - Row-wise union of LEFT/RIGHT → fill [xmin:xmax]
      - Assign LEFT/RIGHT by separator (sep_params) or glottis midline
      - Never draw into glottis
    """
    H, W = raw_mask_with_folds.shape
    out = np.zeros_like(raw_mask_with_folds, dtype=np.uint8)

    g = (dst_glottis_mask == GLOTTIS)
    out[g] = GLOTTIS

    if sep_params is None:
        p1, p2 = _midline_from_glottis(dst_glottis_mask)
        x_line = _line_x_of_y(p1, p2, H)
    else:
        a,b = sep_params
        y = np.arange(H, dtype=np.float32)
        x_line = a*y + b

    folds = (raw_mask_with_folds == RIGHT) | (raw_mask_with_folds == LEFT)

    for y in range(H):
        xs = np.where(folds[y])[0]
        if xs.size == 0:
            continue
        xmin, xmax = int(xs.min()), int(xs.max())
        x_range = np.arange(xmin, xmax + 1)
        right_side = (x_range >= x_line[y])
        cls_arr = np.where(right_side, LEFT, RIGHT).astype(np.uint8)
        not_g = ~g[y, x_range]
        to_write = x_range[not_g]
        if to_write.size:
            out[y, to_write] = cls_arr[not_g]

    return out

def _compose_with_glottis_current(raw_mask_with_folds, sep_params_for_frame, dst_glottis_mask):
    underlay = _solid_underlay_from_folds(raw_mask_with_folds, dst_glottis_mask, sep_params_for_frame)
    underlay[dst_glottis_mask == GLOTTIS] = GLOTTIS
    return underlay

def _compose_for_target_frame(raw_src_mask_with_folds, target_original_mask, sep_params_for_src=None):
    return _compose_with_glottis_current(raw_src_mask_with_folds, sep_params_for_src, target_original_mask)

# ---------- Main App ----------
def run_fold_editor(seq_dir, zoom=300):
    zoom = int(zoom); assert zoom >= 50
    scale = zoom / 100.0

    rgb_paths  = sorted(glob(os.path.join(seq_dir, "*_rgb.png")))
    mask_paths = [p.replace("_rgb.png","_mask.png") for p in rgb_paths]
    assert len(rgb_paths) > 0, f"No *_rgb.png in {seq_dir}"

    rgbs  = [_read_rgb(p) for p in rgb_paths]
    masks = [_read_mask(p) for p in mask_paths]
    H,W,_ = rgbs[0].shape
    Hs, Ws = int(H*scale), int(W*scale)

    frame_ids = [_parse_frame_id(p) for p in rgb_paths]
    id_to_idx = {fid: i for i, fid in enumerate(frame_ids) if fid is not None}

    committed  = [m.copy() for m in masks]   # raw editable masks
    sep_params = [None for _ in masks]       # (a,b) per frame

    idx = 0
    drawing = False
    drawing_btn = None
    points = []

    moving = False
    move_start_xy = None
    preview_mask = None
    # NEW: track separator during move
    sep_move_start = None     # (a,b) at drag start (or midline-derived)
    sep_preview = None        # separator used for preview while dragging

    win = "FoldEditor"
    cv2.namedWindow(win, cv2.WINDOW_NORMAL)
    cv2.resizeWindow(win, Ws*2, Hs)
    cv2.moveWindow(win, 60, 60)

    def to_canvas_left_xy(xc, yc):
        if 0 <= xc < Ws and 0 <= yc < Hs:
            x = int(xc / scale); y = int(yc / scale)
            return x,y
        return None

    def to_canvas_right_xy(xc, yc):
        xr = xc - Ws
        if 0 <= xr < Ws and 0 <= yc < Hs:
            x = int(xr / scale); y = int(yc / scale)
            return x,y
        return None

    def draw_ui(mask_to_show, sep_for_view):
        rgb = rgbs[idx]
        composed = _compose_with_glottis_current(mask_to_show, sep_for_view, committed[idx])
        L = cv2.resize(rgb, (Ws, Hs), interpolation=cv2.INTER_LINEAR)
        R = cv2.resize(_overlay(rgb, composed), (Ws, Hs), interpolation=cv2.INTER_NEAREST)
        canvas = np.zeros((Hs, Ws*2, 3), dtype=np.uint8)
        canvas[:, :Ws] = cv2.cvtColor(L, cv2.COLOR_RGB2BGR)
        canvas[:, Ws:] = cv2.cvtColor(R, cv2.COLOR_RGB2BGR)

        if drawing and len(points) > 1:
            pts = np.array([[int(x*scale), int(y*scale)] for (y,x) in points], np.int32)
            color = (0,255,0) if drawing_btn=='L' else (0,255,255)
            cv2.polylines(canvas[:, :Ws], [pts], isClosed=False, color=color, thickness=2, lineType=cv2.LINE_AA)

        name = os.path.basename(rgb_paths[idx])
        status = f"{name}   |   LMB: contour(L) / move folds(R)   RMB: separator(L)   |   n=save&next  m=save&propagate  p=prev  q=quit   |   zoom={zoom}%"
        cv2.putText(canvas, status, (10, 24), cv2.FONT_HERSHEY_SIMPLEX, 0.58, (240,240,240), 2, cv2.LINE_AA)
        cv2.putText(canvas, "ORIGINAL", (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (200,200,200), 1, cv2.LINE_AA)
        cv2.putText(canvas, "MASK OVERLAY (composed)", (Ws+10, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (200,200,200), 1, cv2.LINE_AA)
        cv2.imshow("FoldEditor", canvas)

    def _ensure_sep(idx_local):
        """Return a valid separator (a,b) for this frame; if none, derive from GL midline."""
        if sep_params[idx_local] is not None:
            return sep_params[idx_local]
        p1, p2 = _midline_from_glottis(committed[idx_local])
        # compute a,b from two points (y,x): x = a*y + b
        (y1,x1),(y2,x2) = p1,p2
        dy = (y2 - y1)
        a = (x2 - x1) / dy if abs(dy) > 1e-6 else 0.0
        b = x1 - a*y1
        return (a,b)

    def on_mouse(event, x, y, flags, param):
        nonlocal drawing, drawing_btn, points
        nonlocal moving, move_start_xy, preview_mask, sep_move_start, sep_preview

        mL = to_canvas_left_xy(x, y)
        mR = to_canvas_right_xy(x, y)

        # ---- LEFT: polygon
        if event == cv2.EVENT_LBUTTONDOWN and mL is not None:
            drawing = True; drawing_btn = 'L'; points = [(mL[1], mL[0])]
        elif event == cv2.EVENT_MOUSEMOVE and drawing and drawing_btn=='L' and mL is not None:
            py, px = mL[1], mL[0]
            if (py,px) != points[-1]: points.append((py,px))
        elif event == cv2.EVENT_LBUTTONUP and drawing and drawing_btn=='L':
            if len(points) >= 3:
                y0,x0 = points[0]; y1,x1 = points[-1]
                if (x1-x0)**2 + (y1-y0)**2 <= 10**2:
                    poly = np.array([[x,y] for (y,x) in points], np.int32)
                    poly_mask = np.zeros(committed[idx].shape, np.uint8)
                    cv2.fillPoly(poly_mask, [poly], 1)
                    committed[idx] = _apply_polygon_correction(
                        committed[idx], poly_mask.astype(bool), sep_params[idx]
                    )
            drawing = False; drawing_btn = None; points = []

        # ---- LEFT: separator (stores sep_params[idx])
        if event == cv2.EVENT_RBUTTONDOWN and mL is not None:
            drawing = True; drawing_btn = 'R'; points = [(mL[1], mL[0])]
        elif event == cv2.EVENT_MOUSEMOVE and drawing and drawing_btn=='R' and mL is not None:
            py, px = mL[1], mL[0]
            if (py,px) != points[-1]: points.append((py,px))
        elif event == cv2.EVENT_RBUTTONUP and drawing and drawing_btn=='R':
            if len(points) >= 2:
                newm, ab = _apply_separator(committed[idx], points)
                committed[idx] = newm
                sep_params[idx] = ab  # save separator
            drawing = False; drawing_btn = None; points = []

        # ---- RIGHT: move folds **and separator**
        if event == cv2.EVENT_LBUTTONDOWN and mR is not None:
            moving = True
            move_start_xy = (mR[0], mR[1])          # (x,y) in original coords
            preview_mask = committed[idx].copy()
            sep_move_start = _ensure_sep(idx)       # capture a,b at drag start
            sep_preview = sep_move_start

        elif event == cv2.EVENT_MOUSEMOVE and moving and mR is not None and move_start_xy is not None:
            dx = int(round(mR[0] - move_start_xy[0]))
            dy = int(round(mR[1] - move_start_xy[1]))
            # preview folds
            preview_mask = _translate_folds_only(committed[idx], dy, dx)
            # preview separator translation: x' = a*y' + (b - a*dy + dx)
            a0, b0 = sep_move_start
            sep_preview = (a0, b0 - a0*dy + dx)

        elif event == cv2.EVENT_LBUTTONUP and moving:
            if mR is not None and move_start_xy is not None:
                dx = int(round(mR[0] - move_start_xy[0]))
                dy = int(round(mR[1] - move_start_xy[1]))
                committed[idx] = _translate_folds_only(committed[idx], dy, dx)
                # commit translated separator
                a0, b0 = sep_move_start
                sep_params[idx] = (a0, b0 - a0*dy + dx)
            moving = False
            move_start_xy = None
            preview_mask = None
            sep_move_start = None
            sep_preview = None

    cv2.setMouseCallback("FoldEditor", on_mouse)

    print("[FoldEditor] Opened. LMB=contour (left) / move folds+divider (right), RMB=separator (left). 'n' saves & next, 'm' saves & propagates (incl. divider), 'p' prev, 'q' quit.")
    while True:
        # Show composed (no gaps). If moving, compose with sep_preview; else sep_params[idx]
        current_for_view = preview_mask if (moving and preview_mask is not None) else committed[idx]
        sep_for_view = sep_preview if (moving and sep_preview is not None) else sep_params[idx]
        draw_ui(current_for_view, sep_for_view)

        k = cv2.waitKey(20) & 0xFF
        if k == 255:
            continue
        if k == ord('q') or k == 27:
            break

        if k == ord('n'):
            # Save composed current (uses current frame's separator if present; else midline)
            ab = sep_params[idx]
            composed_now = _compose_with_glottis_current(committed[idx], ab, committed[idx])
            out_p = mask_paths[idx].replace("_mask.png", "_mask_corrected.png")
            _save_mask(out_p, composed_now)
            print("saved:", out_p)
            if idx == len(rgbs)-1:
                print("[FoldEditor] Reached last frame. All done.")
            idx = min(len(rgbs)-1, idx+1)

        elif k == ord('m'):
            # Save composed current and propagate folds **and the same separator** to rest of 100-block
            cur_id = frame_ids[idx]
            if cur_id is None:
                print("[WARN] Cannot parse frame id; skipping propagate.")
            else:
                src_raw = committed[idx]
                src_sep = _ensure_sep(idx)            # ensure we have (a,b)
                # save current
                out_cur = mask_paths[idx].replace("_mask.png", "_mask_corrected.png")
                out_mask = _compose_with_glottis_current(src_raw, src_sep, committed[idx])
                _save_mask(out_cur, out_mask)
                print("saved:", out_cur, "(source for propagation, divider included)")

                block_end = _seq_block_end_id(cur_id)
                for target_id in range(cur_id + 1, block_end + 1):
                    j = id_to_idx.get(target_id, None)
                    if j is None:
                        continue
                    dst_composed = _compose_for_target_frame(src_raw, masks[j], src_sep)
                    out_p = mask_paths[j].replace("_mask.png", "_mask_corrected.png")
                    _save_mask(out_p, dst_composed)
                    committed[j] = dst_composed
                    # also propagate the SAME separator to target frames
                    sep_params[j] = src_sep
                    print("propagated to:", out_p)

                if idx == len(rgbs)-1:
                    print("[FoldEditor] Reached last frame. Propagation complete.")
                idx = min(len(rgbs)-1, idx+1)

        elif k == ord('p'):
            idx = max(0, idx-1)

    cv2.destroyAllWindows()
    print("[FoldEditor] Closed.")

# %%
seq_dir = r"C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension"
run_fold_editor(seq_dir)
# Out:
# [FoldEditor] Opened. LMB=contour (left) / move folds+divider (right), RMB=separator (left). 'n' saves & next, 'm' saves & propagates (incl. divider), 'p' prev, 'q' quit.
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48501_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48502_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48503_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48504_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48505_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48506_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48507_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48508_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48509_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48510_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48511_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48512_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48513_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48514_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48515_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48516_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48517_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48518_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48519_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48520_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48521_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48522_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48523_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48524_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48525_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48526_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48527_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48528_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48529_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48530_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48531_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48532_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48533_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48534_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48535_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48536_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48537_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48538_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48539_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48540_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48541_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48542_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48543_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48544_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48545_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48546_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48547_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48548_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48549_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48550_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48551_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48552_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48553_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48554_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48555_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48556_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48557_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48558_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48559_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48560_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48561_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48562_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48563_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48564_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48565_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48566_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48567_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48568_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48569_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48570_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48571_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48572_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48573_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48574_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48575_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48576_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48577_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48578_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48579_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48580_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48581_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48582_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48583_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48584_mask_corrected.png
# saved: C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\48585_mask_corrected.png

# %%
import os

def replace_corrected_masks(DIR: str):
    """
    Goes through the specified directory and processes image–mask triplets named like:
    10001_mask.png, 10001_mask_corrected.png, 10001_rgb.png, etc.

    Function behavior:
    1. Deletes all files ending with '_mask' (e.g., '10001_mask.png').
    2. Renames all corresponding '_mask_corrected' files to '_mask'
       (e.g., '10001_mask_corrected.png' → '10001_mask.png').

    This is typically used after manual correction of segmentation masks,
    where corrected masks should replace the original ones.

    Parameters
    ----------
    DIR : str
        Path to the directory containing the triplets.
    """
    for filename in os.listdir(DIR):
        file_path = os.path.join(DIR, filename)

        # Skip non-files (like folders)
        if not os.path.isfile(file_path):
            continue

        # Remove old (non-corrected) mask files
        if filename.endswith('_mask.png') and not filename.endswith('_mask_corrected.png'):
            os.remove(file_path)
            print(f"Removed: {filename}")

        # Rename corrected mask files to standard name
        elif filename.endswith('_mask_corrected.png'):
            new_name = filename.replace('_mask_corrected.png', '_mask.png')
            new_path = os.path.join(DIR, new_name)
            os.rename(file_path, new_path)
            print(f"Renamed: {filename} → {new_name}")

# %%
dir = r"C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension"
replace_corrected_masks(dir)
# Out:
# Removed: 40001_mask.png
# Renamed: 40001_mask_corrected.png → 40001_mask.png
# Removed: 40002_mask.png
# Renamed: 40002_mask_corrected.png → 40002_mask.png
# Removed: 40003_mask.png
# Renamed: 40003_mask_corrected.png → 40003_mask.png
# Removed: 40004_mask.png
# Renamed: 40004_mask_corrected.png → 40004_mask.png
# Removed: 40005_mask.png
# Renamed: 40005_mask_corrected.png → 40005_mask.png
# Removed: 40006_mask.png
# Renamed: 40006_mask_corrected.png → 40006_mask.png
# Removed: 40007_mask.png
# Renamed: 40007_mask_corrected.png → 40007_mask.png
# Removed: 40008_mask.png
# Renamed: 40008_mask_corrected.png → 40008_mask.png
# Removed: 40009_mask.png
# Renamed: 40009_mask_corrected.png → 40009_mask.png
# Removed: 40010_mask.png
# Renamed: 40010_mask_corrected.png → 40010_mask.png
# Removed: 40011_mask.png
# Renamed: 40011_mask_corrected.png → 40011_mask.png
# Removed: 40012_mask.png
# Renamed: 40012_mask_corrected.png → 40012_mask.png
# Removed: 40013_mask.png
# Renamed: 40013_mask_corrected.png → 40013_mask.png
# Removed: 40014_mask.png
# Renamed: 40014_mask_corrected.png → 40014_mask.png
# Removed: 40015_mask.png
# Renamed: 40015_mask_corrected.png → 40015_mask.png
# Removed: 40016_mask.png
# Renamed: 40016_mask_corrected.png → 40016_mask.png
# Removed: 40017_mask.png
# Renamed: 40017_mask_corrected.png → 40017_mask.png
# Removed: 40018_mask.png
# Renamed: 40018_mask_corrected.png → 40018_mask.png
# Removed: 40019_mask.png
# Renamed: 40019_mask_corrected.png → 40019_mask.png
# Removed: 40020_mask.png
# Renamed: 40020_mask_corrected.png → 40020_mask.png
# Removed: 40021_mask.png
# Renamed: 40021_mask_corrected.png → 40021_mask.png
# Removed: 40022_mask.png
# Renamed: 40022_mask_corrected.png → 40022_mask.png
# Removed: 40023_mask.png
# Renamed: 40023_mask_corrected.png → 40023_mask.png
# Removed: 40024_mask.png
# Renamed: 40024_mask_corrected.png → 40024_mask.png
# Removed: 40025_mask.png
# Renamed: 40025_mask_corrected.png → 40025_mask.png
# Removed: 40026_mask.png
# Renamed: 40026_mask_corrected.png → 40026_mask.png
# Removed: 40027_mask.png
# Renamed: 40027_mask_corrected.png → 40027_mask.png
# Removed: 40028_mask.png
# Renamed: 40028_mask_corrected.png → 40028_mask.png
# Removed: 40029_mask.png
# Renamed: 40029_mask_corrected.png → 40029_mask.png
# Removed: 40030_mask.png
# Renamed: 40030_mask_corrected.png → 40030_mask.png
# Removed: 40031_mask.png
# Renamed: 40031_mask_corrected.png → 40031_mask.png
# Removed: 40032_mask.png
# Renamed: 40032_mask_corrected.png → 40032_mask.png
# Removed: 40033_mask.png
# Renamed: 40033_mask_corrected.png → 40033_mask.png
# Removed: 40034_mask.png
# Renamed: 40034_mask_corrected.png → 40034_mask.png
# Removed: 40035_mask.png
# Renamed: 40035_mask_corrected.png → 40035_mask.png
# Removed: 40036_mask.png
# Renamed: 40036_mask_corrected.png → 40036_mask.png
# Removed: 40037_mask.png
# Renamed: 40037_mask_corrected.png → 40037_mask.png
# Removed: 40038_mask.png
# Renamed: 40038_mask_corrected.png → 40038_mask.png
# Removed: 40039_mask.png
# Renamed: 40039_mask_corrected.png → 40039_mask.png
# Removed: 40040_mask.png
# Renamed: 40040_mask_corrected.png → 40040_mask.png
# Removed: 40041_mask.png
# Renamed: 40041_mask_corrected.png → 40041_mask.png
# Removed: 40042_mask.png
# Renamed: 40042_mask_corrected.png → 40042_mask.png
# Removed: 40043_mask.png
# Renamed: 40043_mask_corrected.png → 40043_mask.png
# Removed: 40044_mask.png
# Renamed: 40044_mask_corrected.png → 40044_mask.png
# Removed: 40045_mask.png
# Renamed: 40045_mask_corrected.png → 40045_mask.png
# Removed: 40046_mask.png
# Renamed: 40046_mask_corrected.png → 40046_mask.png
# Removed: 40047_mask.png
# Renamed: 40047_mask_corrected.png → 40047_mask.png
# Removed: 40048_mask.png
# Renamed: 40048_mask_corrected.png → 40048_mask.png
# Removed: 40049_mask.png
# Renamed: 40049_mask_corrected.png → 40049_mask.png
# Removed: 40050_mask.png
# Renamed: 40050_mask_corrected.png → 40050_mask.png
# Removed: 40051_mask.png
# Renamed: 40051_mask_corrected.png → 40051_mask.png
# Removed: 40052_mask.png
# Renamed: 40052_mask_corrected.png → 40052_mask.png
# Removed: 40053_mask.png
# Renamed: 40053_mask_corrected.png → 40053_mask.png
# Removed: 40054_mask.png
# Renamed: 40054_mask_corrected.png → 40054_mask.png
# Removed: 40055_mask.png
# Renamed: 40055_mask_corrected.png → 40055_mask.png
# Removed: 40056_mask.png
# Renamed: 40056_mask_corrected.png → 40056_mask.png
# Removed: 40057_mask.png
# Renamed: 40057_mask_corrected.png → 40057_mask.png
# Removed: 40058_mask.png
# Renamed: 40058_mask_corrected.png → 40058_mask.png
# Removed: 40059_mask.png
# Renamed: 40059_mask_corrected.png → 40059_mask.png
# Removed: 40060_mask.png
# Renamed: 40060_mask_corrected.png → 40060_mask.png
# Removed: 40061_mask.png
# Renamed: 40061_mask_corrected.png → 40061_mask.png
# Removed: 40062_mask.png
# Renamed: 40062_mask_corrected.png → 40062_mask.png
# Removed: 40063_mask.png
# Renamed: 40063_mask_corrected.png → 40063_mask.png
# Removed: 40064_mask.png
# Renamed: 40064_mask_corrected.png → 40064_mask.png
# Removed: 40065_mask.png
# Renamed: 40065_mask_corrected.png → 40065_mask.png
# Removed: 40066_mask.png
# Renamed: 40066_mask_corrected.png → 40066_mask.png
# Removed: 40067_mask.png
# Renamed: 40067_mask_corrected.png → 40067_mask.png
# Removed: 40068_mask.png
# Renamed: 40068_mask_corrected.png → 40068_mask.png
# Removed: 40069_mask.png
# Renamed: 40069_mask_corrected.png → 40069_mask.png
# Removed: 40070_mask.png
# Renamed: 40070_mask_corrected.png → 40070_mask.png
# Removed: 40071_mask.png
# Renamed: 40071_mask_corrected.png → 40071_mask.png
# Removed: 40072_mask.png
# Renamed: 40072_mask_corrected.png → 40072_mask.png
# Removed: 40073_mask.png
# Renamed: 40073_mask_corrected.png → 40073_mask.png
# Removed: 40074_mask.png
# Renamed: 40074_mask_corrected.png → 40074_mask.png
# Removed: 40075_mask.png
# Renamed: 40075_mask_corrected.png → 40075_mask.png
# Removed: 40076_mask.png
# Renamed: 40076_mask_corrected.png → 40076_mask.png
# Removed: 40077_mask.png
# Renamed: 40077_mask_corrected.png → 40077_mask.png
# Removed: 40078_mask.png
# Renamed: 40078_mask_corrected.png → 40078_mask.png
# Removed: 40079_mask.png
# Renamed: 40079_mask_corrected.png → 40079_mask.png
# Removed: 40080_mask.png
# Renamed: 40080_mask_corrected.png → 40080_mask.png
# Removed: 40081_mask.png
# Renamed: 40081_mask_corrected.png → 40081_mask.png
# Removed: 40082_mask.png
# Renamed: 40082_mask_corrected.png → 40082_mask.png
# Removed: 40083_mask.png
# Renamed: 40083_mask_corrected.png → 40083_mask.png
# Removed: 40084_mask.png
# Renamed: 40084_mask_corrected.png → 40084_mask.png
# Removed: 40085_mask.png
# Renamed: 40085_mask_corrected.png → 40085_mask.png
# Removed: 40086_mask.png
# Renamed: 40086_mask_corrected.png → 40086_mask.png
# Removed: 40087_mask.png
# Renamed: 40087_mask_corrected.png → 40087_mask.png
# Removed: 40088_mask.png
# Renamed: 40088_mask_corrected.png → 40088_mask.png
# Removed: 40089_mask.png
# Renamed: 40089_mask_corrected.png → 40089_mask.png
# Removed: 40090_mask.png
# Renamed: 40090_mask_corrected.png → 40090_mask.png
# Removed: 40091_mask.png
# Renamed: 40091_mask_corrected.png → 40091_mask.png
# Removed: 40092_mask.png
# Renamed: 40092_mask_corrected.png → 40092_mask.png
# Removed: 40093_mask.png
# Renamed: 40093_mask_corrected.png → 40093_mask.png
# Removed: 40094_mask.png
# Renamed: 40094_mask_corrected.png → 40094_mask.png
# Removed: 40095_mask.png
# Renamed: 40095_mask_corrected.png → 40095_mask.png
# Removed: 40096_mask.png
# Renamed: 40096_mask_corrected.png → 40096_mask.png
# Removed: 40097_mask.png
# Renamed: 40097_mask_corrected.png → 40097_mask.png
# Removed: 40098_mask.png
# Renamed: 40098_mask_corrected.png → 40098_mask.png
# Removed: 40099_mask.png
# Renamed: 40099_mask_corrected.png → 40099_mask.png
# Removed: 40100_mask.png
# Renamed: 40100_mask_corrected.png → 40100_mask.png
# Removed: 40101_mask.png
# Renamed: 40101_mask_corrected.png → 40101_mask.png
# Removed: 40102_mask.png
# Renamed: 40102_mask_corrected.png → 40102_mask.png
# Removed: 40103_mask.png
# Renamed: 40103_mask_corrected.png → 40103_mask.png
# Removed: 40104_mask.png
# Renamed: 40104_mask_corrected.png → 40104_mask.png
# Removed: 40105_mask.png
# Renamed: 40105_mask_corrected.png → 40105_mask.png
# Removed: 40106_mask.png
# Renamed: 40106_mask_corrected.png → 40106_mask.png
# Removed: 40107_mask.png
# Renamed: 40107_mask_corrected.png → 40107_mask.png
# Removed: 40108_mask.png
# Renamed: 40108_mask_corrected.png → 40108_mask.png
# Removed: 40109_mask.png
# Renamed: 40109_mask_corrected.png → 40109_mask.png
# Removed: 40110_mask.png
# Renamed: 40110_mask_corrected.png → 40110_mask.png
# Removed: 40111_mask.png
# Renamed: 40111_mask_corrected.png → 40111_mask.png
# Removed: 40112_mask.png
# Renamed: 40112_mask_corrected.png → 40112_mask.png
# Removed: 40113_mask.png
# Renamed: 40113_mask_corrected.png → 40113_mask.png
# Removed: 40114_mask.png
# Renamed: 40114_mask_corrected.png → 40114_mask.png
# Removed: 40115_mask.png
# Renamed: 40115_mask_corrected.png → 40115_mask.png
# Removed: 40116_mask.png
# Renamed: 40116_mask_corrected.png → 40116_mask.png
# Removed: 40117_mask.png
# Renamed: 40117_mask_corrected.png → 40117_mask.png
# Removed: 40118_mask.png
# Renamed: 40118_mask_corrected.png → 40118_mask.png
# Removed: 40119_mask.png
# Renamed: 40119_mask_corrected.png → 40119_mask.png
# Removed: 40120_mask.png
# Renamed: 40120_mask_corrected.png → 40120_mask.png
# Removed: 40121_mask.png
# Renamed: 40121_mask_corrected.png → 40121_mask.png
# Removed: 40122_mask.png
# Renamed: 40122_mask_corrected.png → 40122_mask.png
# Removed: 40123_mask.png
# Renamed: 40123_mask_corrected.png → 40123_mask.png
# Removed: 40124_mask.png
# Renamed: 40124_mask_corrected.png → 40124_mask.png
# Removed: 40125_mask.png
# Renamed: 40125_mask_corrected.png → 40125_mask.png
# Removed: 40126_mask.png
# Renamed: 40126_mask_corrected.png → 40126_mask.png
# Removed: 40127_mask.png
# Renamed: 40127_mask_corrected.png → 40127_mask.png
# Removed: 40128_mask.png
# Renamed: 40128_mask_corrected.png → 40128_mask.png
# Removed: 40129_mask.png
# Renamed: 40129_mask_corrected.png → 40129_mask.png
# Removed: 40130_mask.png
# Renamed: 40130_mask_corrected.png → 40130_mask.png
# Removed: 40131_mask.png
# Renamed: 40131_mask_corrected.png → 40131_mask.png
# Removed: 40132_mask.png
# Renamed: 40132_mask_corrected.png → 40132_mask.png
# Removed: 40133_mask.png
# Renamed: 40133_mask_corrected.png → 40133_mask.png
# Removed: 40134_mask.png
# Renamed: 40134_mask_corrected.png → 40134_mask.png
# Removed: 40135_mask.png
# Renamed: 40135_mask_corrected.png → 40135_mask.png
# Removed: 40136_mask.png
# Renamed: 40136_mask_corrected.png → 40136_mask.png
# Removed: 40137_mask.png
# Renamed: 40137_mask_corrected.png → 40137_mask.png
# Removed: 40138_mask.png
# Renamed: 40138_mask_corrected.png → 40138_mask.png
# Removed: 40139_mask.png
# Renamed: 40139_mask_corrected.png → 40139_mask.png
# Removed: 40140_mask.png
# Renamed: 40140_mask_corrected.png → 40140_mask.png
# Removed: 40141_mask.png
# Renamed: 40141_mask_corrected.png → 40141_mask.png
# Removed: 40142_mask.png
# Renamed: 40142_mask_corrected.png → 40142_mask.png
# Removed: 40143_mask.png
# Renamed: 40143_mask_corrected.png → 40143_mask.png
# Removed: 40144_mask.png
# Renamed: 40144_mask_corrected.png → 40144_mask.png
# Removed: 40145_mask.png
# Renamed: 40145_mask_corrected.png → 40145_mask.png
# Removed: 40146_mask.png
# Renamed: 40146_mask_corrected.png → 40146_mask.png
# Removed: 40147_mask.png
# Renamed: 40147_mask_corrected.png → 40147_mask.png
# Removed: 40148_mask.png
# Renamed: 40148_mask_corrected.png → 40148_mask.png
# Removed: 40149_mask.png
# Renamed: 40149_mask_corrected.png → 40149_mask.png
# Removed: 40150_mask.png
# Renamed: 40150_mask_corrected.png → 40150_mask.png
# Removed: 40151_mask.png
# Renamed: 40151_mask_corrected.png → 40151_mask.png
# Removed: 40152_mask.png
# Renamed: 40152_mask_corrected.png → 40152_mask.png
# Removed: 40153_mask.png
# Renamed: 40153_mask_corrected.png → 40153_mask.png
# Removed: 40154_mask.png
# Renamed: 40154_mask_corrected.png → 40154_mask.png
# Removed: 40155_mask.png
# Renamed: 40155_mask_corrected.png → 40155_mask.png
# Removed: 40156_mask.png
# Renamed: 40156_mask_corrected.png → 40156_mask.png
# Removed: 40157_mask.png
# Renamed: 40157_mask_corrected.png → 40157_mask.png
# Removed: 40158_mask.png
# Renamed: 40158_mask_corrected.png → 40158_mask.png
# Removed: 40159_mask.png
# Renamed: 40159_mask_corrected.png → 40159_mask.png
# Removed: 40160_mask.png
# Renamed: 40160_mask_corrected.png → 40160_mask.png
# Removed: 40161_mask.png
# Renamed: 40161_mask_corrected.png → 40161_mask.png
# Removed: 40162_mask.png
# Renamed: 40162_mask_corrected.png → 40162_mask.png
# Removed: 40163_mask.png
# Renamed: 40163_mask_corrected.png → 40163_mask.png
# Removed: 40164_mask.png
# Renamed: 40164_mask_corrected.png → 40164_mask.png
# Removed: 40165_mask.png
# Renamed: 40165_mask_corrected.png → 40165_mask.png
# Removed: 40166_mask.png
# Renamed: 40166_mask_corrected.png → 40166_mask.png
# Removed: 40167_mask.png
# Renamed: 40167_mask_corrected.png → 40167_mask.png
# Removed: 40168_mask.png
# Renamed: 40168_mask_corrected.png → 40168_mask.png
# Removed: 40169_mask.png
# Renamed: 40169_mask_corrected.png → 40169_mask.png
# Removed: 40170_mask.png
# Renamed: 40170_mask_corrected.png → 40170_mask.png
# Removed: 40171_mask.png
# Renamed: 40171_mask_corrected.png → 40171_mask.png
# Removed: 40172_mask.png
# Renamed: 40172_mask_corrected.png → 40172_mask.png
# Removed: 40173_mask.png
# Renamed: 40173_mask_corrected.png → 40173_mask.png
# Removed: 40174_mask.png
# Renamed: 40174_mask_corrected.png → 40174_mask.png
# Removed: 40175_mask.png
# Renamed: 40175_mask_corrected.png → 40175_mask.png
# Removed: 40176_mask.png
# Renamed: 40176_mask_corrected.png → 40176_mask.png
# Removed: 40177_mask.png
# Renamed: 40177_mask_corrected.png → 40177_mask.png
# Removed: 40178_mask.png
# Renamed: 40178_mask_corrected.png → 40178_mask.png
# Removed: 40179_mask.png
# Renamed: 40179_mask_corrected.png → 40179_mask.png
# Removed: 40180_mask.png
# Renamed: 40180_mask_corrected.png → 40180_mask.png
# Removed: 40181_mask.png
# Renamed: 40181_mask_corrected.png → 40181_mask.png
# Removed: 40182_mask.png
# Renamed: 40182_mask_corrected.png → 40182_mask.png
# Removed: 40183_mask.png
# Renamed: 40183_mask_corrected.png → 40183_mask.png
# Removed: 40184_mask.png
# Renamed: 40184_mask_corrected.png → 40184_mask.png
# Removed: 40185_mask.png
# Renamed: 40185_mask_corrected.png → 40185_mask.png
# Removed: 40186_mask.png
# Renamed: 40186_mask_corrected.png → 40186_mask.png
# Removed: 40187_mask.png
# Renamed: 40187_mask_corrected.png → 40187_mask.png
# Removed: 40188_mask.png
# Renamed: 40188_mask_corrected.png → 40188_mask.png
# Removed: 40189_mask.png
# Renamed: 40189_mask_corrected.png → 40189_mask.png
# Removed: 40190_mask.png
# Renamed: 40190_mask_corrected.png → 40190_mask.png
# Removed: 40191_mask.png
# Renamed: 40191_mask_corrected.png → 40191_mask.png
# Removed: 40192_mask.png
# Renamed: 40192_mask_corrected.png → 40192_mask.png
# Removed: 40193_mask.png
# Renamed: 40193_mask_corrected.png → 40193_mask.png
# Removed: 40194_mask.png
# Renamed: 40194_mask_corrected.png → 40194_mask.png
# Removed: 40195_mask.png
# Renamed: 40195_mask_corrected.png → 40195_mask.png
# Removed: 40196_mask.png
# Renamed: 40196_mask_corrected.png → 40196_mask.png
# Removed: 40197_mask.png
# Renamed: 40197_mask_corrected.png → 40197_mask.png
# Removed: 40198_mask.png
# Renamed: 40198_mask_corrected.png → 40198_mask.png
# Removed: 40199_mask.png
# Renamed: 40199_mask_corrected.png → 40199_mask.png
# Removed: 40200_mask.png
# Renamed: 40200_mask_corrected.png → 40200_mask.png
# Removed: 40201_mask.png
# Renamed: 40201_mask_corrected.png → 40201_mask.png
# Removed: 40202_mask.png
# Renamed: 40202_mask_corrected.png → 40202_mask.png
# Removed: 40203_mask.png
# Renamed: 40203_mask_corrected.png → 40203_mask.png
# Removed: 40204_mask.png
# Renamed: 40204_mask_corrected.png → 40204_mask.png
# Removed: 40205_mask.png
# Renamed: 40205_mask_corrected.png → 40205_mask.png
# Removed: 40206_mask.png
# Renamed: 40206_mask_corrected.png → 40206_mask.png
# Removed: 40207_mask.png
# Renamed: 40207_mask_corrected.png → 40207_mask.png
# Removed: 40208_mask.png
# Renamed: 40208_mask_corrected.png → 40208_mask.png
# Removed: 40209_mask.png
# Renamed: 40209_mask_corrected.png → 40209_mask.png
# Removed: 40210_mask.png
# Renamed: 40210_mask_corrected.png → 40210_mask.png
# Removed: 40211_mask.png
# Renamed: 40211_mask_corrected.png → 40211_mask.png
# Removed: 40212_mask.png
# Renamed: 40212_mask_corrected.png → 40212_mask.png
# Removed: 40213_mask.png
# Renamed: 40213_mask_corrected.png → 40213_mask.png
# Removed: 40214_mask.png
# Renamed: 40214_mask_corrected.png → 40214_mask.png
# Removed: 40215_mask.png
# Renamed: 40215_mask_corrected.png → 40215_mask.png
# Removed: 40216_mask.png
# Renamed: 40216_mask_corrected.png → 40216_mask.png
# Removed: 40217_mask.png
# Renamed: 40217_mask_corrected.png → 40217_mask.png
# Removed: 40218_mask.png
# Renamed: 40218_mask_corrected.png → 40218_mask.png
# Removed: 40219_mask.png
# Renamed: 40219_mask_corrected.png → 40219_mask.png
# Removed: 40220_mask.png
# Renamed: 40220_mask_corrected.png → 40220_mask.png
# Removed: 40221_mask.png
# Renamed: 40221_mask_corrected.png → 40221_mask.png
# Removed: 40222_mask.png
# Renamed: 40222_mask_corrected.png → 40222_mask.png
# Removed: 40223_mask.png
# Renamed: 40223_mask_corrected.png → 40223_mask.png
# Removed: 40224_mask.png
# Renamed: 40224_mask_corrected.png → 40224_mask.png
# Removed: 40225_mask.png
# Renamed: 40225_mask_corrected.png → 40225_mask.png
# Removed: 40226_mask.png
# Renamed: 40226_mask_corrected.png → 40226_mask.png
# Removed: 40227_mask.png
# Renamed: 40227_mask_corrected.png → 40227_mask.png
# Removed: 40228_mask.png
# Renamed: 40228_mask_corrected.png → 40228_mask.png
# Removed: 40229_mask.png
# Renamed: 40229_mask_corrected.png → 40229_mask.png
# Removed: 40230_mask.png
# Renamed: 40230_mask_corrected.png → 40230_mask.png
# Removed: 40231_mask.png
# Renamed: 40231_mask_corrected.png → 40231_mask.png
# Removed: 40232_mask.png
# Renamed: 40232_mask_corrected.png → 40232_mask.png
# Removed: 40233_mask.png
# Renamed: 40233_mask_corrected.png → 40233_mask.png
# Removed: 40234_mask.png
# Renamed: 40234_mask_corrected.png → 40234_mask.png
# Removed: 40235_mask.png
# Renamed: 40235_mask_corrected.png → 40235_mask.png
# Removed: 40236_mask.png
# Renamed: 40236_mask_corrected.png → 40236_mask.png
# Removed: 40237_mask.png
# Renamed: 40237_mask_corrected.png → 40237_mask.png
# Removed: 40238_mask.png
# Renamed: 40238_mask_corrected.png → 40238_mask.png
# Removed: 40239_mask.png
# Renamed: 40239_mask_corrected.png → 40239_mask.png
# Removed: 40240_mask.png
# Renamed: 40240_mask_corrected.png → 40240_mask.png
# Removed: 40241_mask.png
# Renamed: 40241_mask_corrected.png → 40241_mask.png
# Removed: 40242_mask.png
# Renamed: 40242_mask_corrected.png → 40242_mask.png
# Removed: 40243_mask.png
# Renamed: 40243_mask_corrected.png → 40243_mask.png
# Removed: 40244_mask.png
# Renamed: 40244_mask_corrected.png → 40244_mask.png
# Removed: 40245_mask.png
# Renamed: 40245_mask_corrected.png → 40245_mask.png
# Removed: 40246_mask.png
# Renamed: 40246_mask_corrected.png → 40246_mask.png
# Removed: 40247_mask.png
# Renamed: 40247_mask_corrected.png → 40247_mask.png
# Removed: 40248_mask.png
# Renamed: 40248_mask_corrected.png → 40248_mask.png
# Removed: 40249_mask.png
# Renamed: 40249_mask_corrected.png → 40249_mask.png
# Removed: 40250_mask.png
# Renamed: 40250_mask_corrected.png → 40250_mask.png
# Removed: 40251_mask.png
# Renamed: 40251_mask_corrected.png → 40251_mask.png
# Removed: 40252_mask.png
# Renamed: 40252_mask_corrected.png → 40252_mask.png
# Removed: 40253_mask.png
# Renamed: 40253_mask_corrected.png → 40253_mask.png
# Removed: 40254_mask.png
# Renamed: 40254_mask_corrected.png → 40254_mask.png
# Removed: 40255_mask.png
# Renamed: 40255_mask_corrected.png → 40255_mask.png
# Removed: 40256_mask.png
# Renamed: 40256_mask_corrected.png → 40256_mask.png
# Removed: 40257_mask.png
# Renamed: 40257_mask_corrected.png → 40257_mask.png
# Removed: 40258_mask.png
# Renamed: 40258_mask_corrected.png → 40258_mask.png
# Removed: 40259_mask.png
# Renamed: 40259_mask_corrected.png → 40259_mask.png
# Removed: 40260_mask.png
# Renamed: 40260_mask_corrected.png → 40260_mask.png
# Removed: 40261_mask.png
# Renamed: 40261_mask_corrected.png → 40261_mask.png
# Removed: 40262_mask.png
# Renamed: 40262_mask_corrected.png → 40262_mask.png
# Removed: 40263_mask.png
# Renamed: 40263_mask_corrected.png → 40263_mask.png
# Removed: 40264_mask.png
# Renamed: 40264_mask_corrected.png → 40264_mask.png
# Removed: 40265_mask.png
# Renamed: 40265_mask_corrected.png → 40265_mask.png
# Removed: 40266_mask.png
# Renamed: 40266_mask_corrected.png → 40266_mask.png
# Removed: 40267_mask.png
# Renamed: 40267_mask_corrected.png → 40267_mask.png
# Removed: 40268_mask.png
# Renamed: 40268_mask_corrected.png → 40268_mask.png
# Removed: 40269_mask.png
# Renamed: 40269_mask_corrected.png → 40269_mask.png
# Removed: 40270_mask.png
# Renamed: 40270_mask_corrected.png → 40270_mask.png
# Removed: 40271_mask.png
# Renamed: 40271_mask_corrected.png → 40271_mask.png
# Removed: 40272_mask.png
# Renamed: 40272_mask_corrected.png → 40272_mask.png
# Removed: 40273_mask.png
# Renamed: 40273_mask_corrected.png → 40273_mask.png
# Removed: 40274_mask.png
# Renamed: 40274_mask_corrected.png → 40274_mask.png
# Removed: 40275_mask.png
# Renamed: 40275_mask_corrected.png → 40275_mask.png
# Removed: 40276_mask.png
# Renamed: 40276_mask_corrected.png → 40276_mask.png
# Removed: 40277_mask.png
# Renamed: 40277_mask_corrected.png → 40277_mask.png
# Removed: 40278_mask.png
# Renamed: 40278_mask_corrected.png → 40278_mask.png
# Removed: 40279_mask.png
# Renamed: 40279_mask_corrected.png → 40279_mask.png
# Removed: 40280_mask.png
# Renamed: 40280_mask_corrected.png → 40280_mask.png
# Removed: 40281_mask.png
# Renamed: 40281_mask_corrected.png → 40281_mask.png
# Removed: 40282_mask.png
# Renamed: 40282_mask_corrected.png → 40282_mask.png
# Removed: 40283_mask.png
# Renamed: 40283_mask_corrected.png → 40283_mask.png
# Removed: 40284_mask.png
# Renamed: 40284_mask_corrected.png → 40284_mask.png
# Removed: 40285_mask.png
# Renamed: 40285_mask_corrected.png → 40285_mask.png
# Removed: 40286_mask.png
# Renamed: 40286_mask_corrected.png → 40286_mask.png
# Removed: 40287_mask.png
# Renamed: 40287_mask_corrected.png → 40287_mask.png
# Removed: 40288_mask.png
# Renamed: 40288_mask_corrected.png → 40288_mask.png
# Removed: 40289_mask.png
# Renamed: 40289_mask_corrected.png → 40289_mask.png
# Removed: 40290_mask.png
# Renamed: 40290_mask_corrected.png → 40290_mask.png
# Removed: 40291_mask.png
# Renamed: 40291_mask_corrected.png → 40291_mask.png
# Removed: 40292_mask.png
# Renamed: 40292_mask_corrected.png → 40292_mask.png
# Removed: 40293_mask.png
# Renamed: 40293_mask_corrected.png → 40293_mask.png
# Removed: 40294_mask.png
# Renamed: 40294_mask_corrected.png → 40294_mask.png
# Removed: 40295_mask.png
# Renamed: 40295_mask_corrected.png → 40295_mask.png
# Removed: 40296_mask.png
# Renamed: 40296_mask_corrected.png → 40296_mask.png
# Removed: 40297_mask.png
# Renamed: 40297_mask_corrected.png → 40297_mask.png
# Removed: 40298_mask.png
# Renamed: 40298_mask_corrected.png → 40298_mask.png
# Removed: 40299_mask.png
# Renamed: 40299_mask_corrected.png → 40299_mask.png
# Removed: 40300_mask.png
# Renamed: 40300_mask_corrected.png → 40300_mask.png
# Removed: 40301_mask.png
# Renamed: 40301_mask_corrected.png → 40301_mask.png
# Removed: 40302_mask.png
# Renamed: 40302_mask_corrected.png → 40302_mask.png
# Removed: 40303_mask.png
# Renamed: 40303_mask_corrected.png → 40303_mask.png
# Removed: 40304_mask.png
# Renamed: 40304_mask_corrected.png → 40304_mask.png
# Removed: 40305_mask.png
# Renamed: 40305_mask_corrected.png → 40305_mask.png
# Removed: 40306_mask.png
# Renamed: 40306_mask_corrected.png → 40306_mask.png
# Removed: 40307_mask.png
# Renamed: 40307_mask_corrected.png → 40307_mask.png
# Removed: 40308_mask.png
# Renamed: 40308_mask_corrected.png → 40308_mask.png
# Removed: 40309_mask.png
# Renamed: 40309_mask_corrected.png → 40309_mask.png
# Removed: 40310_mask.png
# Renamed: 40310_mask_corrected.png → 40310_mask.png
# Removed: 40311_mask.png
# Renamed: 40311_mask_corrected.png → 40311_mask.png
# Removed: 40312_mask.png
# Renamed: 40312_mask_corrected.png → 40312_mask.png
# Removed: 40313_mask.png
# Renamed: 40313_mask_corrected.png → 40313_mask.png
# Removed: 40314_mask.png
# Renamed: 40314_mask_corrected.png → 40314_mask.png
# Removed: 40315_mask.png
# Renamed: 40315_mask_corrected.png → 40315_mask.png
# Removed: 40316_mask.png
# Renamed: 40316_mask_corrected.png → 40316_mask.png
# Removed: 40317_mask.png
# Renamed: 40317_mask_corrected.png → 40317_mask.png
# Removed: 40318_mask.png
# Renamed: 40318_mask_corrected.png → 40318_mask.png
# Removed: 40319_mask.png
# Renamed: 40319_mask_corrected.png → 40319_mask.png
# Removed: 40320_mask.png
# Renamed: 40320_mask_corrected.png → 40320_mask.png
# Removed: 40321_mask.png
# Renamed: 40321_mask_corrected.png → 40321_mask.png
# Removed: 40322_mask.png
# Renamed: 40322_mask_corrected.png → 40322_mask.png
# Removed: 40323_mask.png
# Renamed: 40323_mask_corrected.png → 40323_mask.png
# Removed: 40324_mask.png
# Renamed: 40324_mask_corrected.png → 40324_mask.png
# Removed: 40325_mask.png
# Renamed: 40325_mask_corrected.png → 40325_mask.png
# Removed: 40326_mask.png
# Renamed: 40326_mask_corrected.png → 40326_mask.png
# Removed: 40327_mask.png
# Renamed: 40327_mask_corrected.png → 40327_mask.png
# Removed: 40328_mask.png
# Renamed: 40328_mask_corrected.png → 40328_mask.png
# Removed: 40329_mask.png
# Renamed: 40329_mask_corrected.png → 40329_mask.png
# Removed: 40330_mask.png
# Renamed: 40330_mask_corrected.png → 40330_mask.png
# Removed: 40331_mask.png
# Renamed: 40331_mask_corrected.png → 40331_mask.png
# Removed: 40332_mask.png
# Renamed: 40332_mask_corrected.png → 40332_mask.png
# Removed: 40333_mask.png
# Renamed: 40333_mask_corrected.png → 40333_mask.png
# Removed: 40334_mask.png
# Renamed: 40334_mask_corrected.png → 40334_mask.png
# Removed: 40335_mask.png
# Renamed: 40335_mask_corrected.png → 40335_mask.png
# Removed: 40336_mask.png
# Renamed: 40336_mask_corrected.png → 40336_mask.png
# Removed: 40337_mask.png
# Renamed: 40337_mask_corrected.png → 40337_mask.png
# Removed: 40338_mask.png
# Renamed: 40338_mask_corrected.png → 40338_mask.png
# Removed: 40339_mask.png
# Renamed: 40339_mask_corrected.png → 40339_mask.png
# Removed: 40340_mask.png
# Renamed: 40340_mask_corrected.png → 40340_mask.png
# Removed: 40341_mask.png
# Renamed: 40341_mask_corrected.png → 40341_mask.png
# Removed: 40342_mask.png
# Renamed: 40342_mask_corrected.png → 40342_mask.png
# Removed: 40343_mask.png
# Renamed: 40343_mask_corrected.png → 40343_mask.png
# Removed: 40344_mask.png
# Renamed: 40344_mask_corrected.png → 40344_mask.png
# Removed: 40345_mask.png
# Renamed: 40345_mask_corrected.png → 40345_mask.png
# Removed: 40346_mask.png
# Renamed: 40346_mask_corrected.png → 40346_mask.png
# Removed: 40347_mask.png
# Renamed: 40347_mask_corrected.png → 40347_mask.png
# Removed: 40348_mask.png
# Renamed: 40348_mask_corrected.png → 40348_mask.png
# Removed: 40349_mask.png
# Renamed: 40349_mask_corrected.png → 40349_mask.png
# Removed: 40350_mask.png
# Renamed: 40350_mask_corrected.png → 40350_mask.png
# Removed: 40351_mask.png
# Renamed: 40351_mask_corrected.png → 40351_mask.png
# Removed: 40352_mask.png
# Renamed: 40352_mask_corrected.png → 40352_mask.png
# Removed: 40353_mask.png
# Renamed: 40353_mask_corrected.png → 40353_mask.png
# Removed: 40354_mask.png
# Renamed: 40354_mask_corrected.png → 40354_mask.png
# Removed: 40355_mask.png
# Renamed: 40355_mask_corrected.png → 40355_mask.png
# Removed: 40356_mask.png
# Renamed: 40356_mask_corrected.png → 40356_mask.png
# Removed: 40357_mask.png
# Renamed: 40357_mask_corrected.png → 40357_mask.png
# Removed: 40358_mask.png
# Renamed: 40358_mask_corrected.png → 40358_mask.png
# Removed: 40359_mask.png
# Renamed: 40359_mask_corrected.png → 40359_mask.png
# Removed: 40360_mask.png
# Renamed: 40360_mask_corrected.png → 40360_mask.png
# Removed: 40361_mask.png
# Renamed: 40361_mask_corrected.png → 40361_mask.png
# Removed: 40362_mask.png
# Renamed: 40362_mask_corrected.png → 40362_mask.png
# Removed: 40363_mask.png
# Renamed: 40363_mask_corrected.png → 40363_mask.png
# Removed: 40364_mask.png
# Renamed: 40364_mask_corrected.png → 40364_mask.png
# Removed: 40365_mask.png
# Renamed: 40365_mask_corrected.png → 40365_mask.png
# Removed: 40366_mask.png
# Renamed: 40366_mask_corrected.png → 40366_mask.png
# Removed: 40367_mask.png
# Renamed: 40367_mask_corrected.png → 40367_mask.png
# Removed: 40368_mask.png
# Renamed: 40368_mask_corrected.png → 40368_mask.png
# Removed: 40369_mask.png
# Renamed: 40369_mask_corrected.png → 40369_mask.png
# Removed: 40370_mask.png
# Renamed: 40370_mask_corrected.png → 40370_mask.png
# Removed: 40371_mask.png
# Renamed: 40371_mask_corrected.png → 40371_mask.png
# Removed: 40372_mask.png
# Renamed: 40372_mask_corrected.png → 40372_mask.png
# Removed: 40373_mask.png
# Renamed: 40373_mask_corrected.png → 40373_mask.png
# Removed: 40374_mask.png
# Renamed: 40374_mask_corrected.png → 40374_mask.png
# Removed: 40375_mask.png
# Renamed: 40375_mask_corrected.png → 40375_mask.png
# Removed: 40376_mask.png
# Renamed: 40376_mask_corrected.png → 40376_mask.png
# Removed: 40377_mask.png
# Renamed: 40377_mask_corrected.png → 40377_mask.png
# Removed: 40378_mask.png
# Renamed: 40378_mask_corrected.png → 40378_mask.png
# Removed: 40379_mask.png
# Renamed: 40379_mask_corrected.png → 40379_mask.png
# Removed: 40380_mask.png
# Renamed: 40380_mask_corrected.png → 40380_mask.png
# Removed: 40381_mask.png
# Renamed: 40381_mask_corrected.png → 40381_mask.png
# Removed: 40382_mask.png
# Renamed: 40382_mask_corrected.png → 40382_mask.png
# Removed: 40383_mask.png
# Renamed: 40383_mask_corrected.png → 40383_mask.png
# Removed: 40384_mask.png
# Renamed: 40384_mask_corrected.png → 40384_mask.png
# Removed: 40385_mask.png
# Renamed: 40385_mask_corrected.png → 40385_mask.png
# Removed: 40386_mask.png
# Renamed: 40386_mask_corrected.png → 40386_mask.png
# Removed: 40387_mask.png
# Renamed: 40387_mask_corrected.png → 40387_mask.png
# Removed: 40388_mask.png
# Renamed: 40388_mask_corrected.png → 40388_mask.png
# Removed: 40389_mask.png
# Renamed: 40389_mask_corrected.png → 40389_mask.png
# Removed: 40390_mask.png
# Renamed: 40390_mask_corrected.png → 40390_mask.png
# Removed: 40391_mask.png
# Renamed: 40391_mask_corrected.png → 40391_mask.png
# Removed: 40392_mask.png
# Renamed: 40392_mask_corrected.png → 40392_mask.png
# Removed: 40393_mask.png
# Renamed: 40393_mask_corrected.png → 40393_mask.png
# Removed: 40394_mask.png
# Renamed: 40394_mask_corrected.png → 40394_mask.png
# Removed: 40395_mask.png
# Renamed: 40395_mask_corrected.png → 40395_mask.png
# Removed: 40396_mask.png
# Renamed: 40396_mask_corrected.png → 40396_mask.png
# Removed: 40397_mask.png
# Renamed: 40397_mask_corrected.png → 40397_mask.png
# Removed: 40398_mask.png
# Renamed: 40398_mask_corrected.png → 40398_mask.png
# Removed: 40399_mask.png
# Renamed: 40399_mask_corrected.png → 40399_mask.png
# Removed: 40400_mask.png
# Renamed: 40400_mask_corrected.png → 40400_mask.png
# Removed: 40401_mask.png
# Renamed: 40401_mask_corrected.png → 40401_mask.png
# Removed: 40402_mask.png
# Renamed: 40402_mask_corrected.png → 40402_mask.png
# Removed: 40403_mask.png
# Renamed: 40403_mask_corrected.png → 40403_mask.png
# Removed: 40404_mask.png
# Renamed: 40404_mask_corrected.png → 40404_mask.png
# Removed: 40405_mask.png
# Renamed: 40405_mask_corrected.png → 40405_mask.png
# Removed: 40406_mask.png
# Renamed: 40406_mask_corrected.png → 40406_mask.png
# Removed: 40407_mask.png
# Renamed: 40407_mask_corrected.png → 40407_mask.png
# Removed: 40408_mask.png
# Renamed: 40408_mask_corrected.png → 40408_mask.png
# Removed: 40409_mask.png
# Renamed: 40409_mask_corrected.png → 40409_mask.png
# Removed: 40410_mask.png
# Renamed: 40410_mask_corrected.png → 40410_mask.png
# Removed: 40411_mask.png
# Renamed: 40411_mask_corrected.png → 40411_mask.png
# Removed: 40412_mask.png
# Renamed: 40412_mask_corrected.png → 40412_mask.png
# Removed: 40413_mask.png
# Renamed: 40413_mask_corrected.png → 40413_mask.png
# Removed: 40414_mask.png
# Renamed: 40414_mask_corrected.png → 40414_mask.png
# Removed: 40415_mask.png
# Renamed: 40415_mask_corrected.png → 40415_mask.png
# Removed: 40416_mask.png
# Renamed: 40416_mask_corrected.png → 40416_mask.png
# Removed: 40417_mask.png
# Renamed: 40417_mask_corrected.png → 40417_mask.png
# Removed: 40418_mask.png
# Renamed: 40418_mask_corrected.png → 40418_mask.png
# Removed: 40419_mask.png
# Renamed: 40419_mask_corrected.png → 40419_mask.png
# Removed: 40420_mask.png
# Renamed: 40420_mask_corrected.png → 40420_mask.png
# Removed: 40421_mask.png
# Renamed: 40421_mask_corrected.png → 40421_mask.png
# Removed: 40422_mask.png
# Renamed: 40422_mask_corrected.png → 40422_mask.png
# Removed: 40423_mask.png
# Renamed: 40423_mask_corrected.png → 40423_mask.png
# Removed: 40424_mask.png
# Renamed: 40424_mask_corrected.png → 40424_mask.png
# Removed: 40425_mask.png
# Renamed: 40425_mask_corrected.png → 40425_mask.png
# Removed: 40426_mask.png
# Renamed: 40426_mask_corrected.png → 40426_mask.png
# Removed: 40427_mask.png
# Renamed: 40427_mask_corrected.png → 40427_mask.png
# Removed: 40428_mask.png
# Renamed: 40428_mask_corrected.png → 40428_mask.png
# Removed: 40429_mask.png
# Renamed: 40429_mask_corrected.png → 40429_mask.png
# Removed: 40430_mask.png
# Renamed: 40430_mask_corrected.png → 40430_mask.png
# Removed: 40431_mask.png
# Renamed: 40431_mask_corrected.png → 40431_mask.png
# Removed: 40432_mask.png
# Renamed: 40432_mask_corrected.png → 40432_mask.png
# Removed: 40433_mask.png
# Renamed: 40433_mask_corrected.png → 40433_mask.png
# Removed: 40434_mask.png
# Renamed: 40434_mask_corrected.png → 40434_mask.png
# Removed: 40435_mask.png
# Renamed: 40435_mask_corrected.png → 40435_mask.png
# Removed: 40436_mask.png
# Renamed: 40436_mask_corrected.png → 40436_mask.png
# Removed: 40437_mask.png
# Renamed: 40437_mask_corrected.png → 40437_mask.png
# Removed: 40438_mask.png
# Renamed: 40438_mask_corrected.png → 40438_mask.png
# Removed: 40439_mask.png
# Renamed: 40439_mask_corrected.png → 40439_mask.png
# Removed: 40440_mask.png
# Renamed: 40440_mask_corrected.png → 40440_mask.png
# Removed: 40441_mask.png
# Renamed: 40441_mask_corrected.png → 40441_mask.png
# Removed: 40442_mask.png
# Renamed: 40442_mask_corrected.png → 40442_mask.png
# Removed: 40443_mask.png
# Renamed: 40443_mask_corrected.png → 40443_mask.png
# Removed: 40444_mask.png
# Renamed: 40444_mask_corrected.png → 40444_mask.png
# Removed: 40445_mask.png
# Renamed: 40445_mask_corrected.png → 40445_mask.png
# Removed: 40446_mask.png
# Renamed: 40446_mask_corrected.png → 40446_mask.png
# Removed: 40447_mask.png
# Renamed: 40447_mask_corrected.png → 40447_mask.png
# Removed: 40448_mask.png
# Renamed: 40448_mask_corrected.png → 40448_mask.png
# Removed: 40449_mask.png
# Renamed: 40449_mask_corrected.png → 40449_mask.png
# Removed: 40450_mask.png
# Renamed: 40450_mask_corrected.png → 40450_mask.png
# Removed: 40451_mask.png
# Renamed: 40451_mask_corrected.png → 40451_mask.png
# Removed: 40452_mask.png
# Renamed: 40452_mask_corrected.png → 40452_mask.png
# Removed: 40453_mask.png
# Renamed: 40453_mask_corrected.png → 40453_mask.png
# Removed: 40454_mask.png
# Renamed: 40454_mask_corrected.png → 40454_mask.png
# Removed: 40455_mask.png
# Renamed: 40455_mask_corrected.png → 40455_mask.png
# Removed: 40456_mask.png
# Renamed: 40456_mask_corrected.png → 40456_mask.png
# Removed: 40457_mask.png
# Renamed: 40457_mask_corrected.png → 40457_mask.png
# Removed: 40458_mask.png
# Renamed: 40458_mask_corrected.png → 40458_mask.png
# Removed: 40459_mask.png
# Renamed: 40459_mask_corrected.png → 40459_mask.png
# Removed: 40460_mask.png
# Renamed: 40460_mask_corrected.png → 40460_mask.png
# Removed: 40461_mask.png
# Renamed: 40461_mask_corrected.png → 40461_mask.png
# Removed: 40462_mask.png
# Renamed: 40462_mask_corrected.png → 40462_mask.png
# Removed: 40463_mask.png
# Renamed: 40463_mask_corrected.png → 40463_mask.png
# Removed: 40464_mask.png
# Renamed: 40464_mask_corrected.png → 40464_mask.png
# Removed: 40465_mask.png
# Renamed: 40465_mask_corrected.png → 40465_mask.png
# Removed: 40466_mask.png
# Renamed: 40466_mask_corrected.png → 40466_mask.png
# Removed: 40467_mask.png
# Renamed: 40467_mask_corrected.png → 40467_mask.png
# Removed: 40468_mask.png
# Renamed: 40468_mask_corrected.png → 40468_mask.png
# Removed: 40469_mask.png
# Renamed: 40469_mask_corrected.png → 40469_mask.png
# Removed: 40470_mask.png
# Renamed: 40470_mask_corrected.png → 40470_mask.png
# Removed: 40471_mask.png
# Renamed: 40471_mask_corrected.png → 40471_mask.png
# Removed: 40472_mask.png
# Renamed: 40472_mask_corrected.png → 40472_mask.png
# Removed: 40473_mask.png
# Renamed: 40473_mask_corrected.png → 40473_mask.png
# Removed: 40474_mask.png
# Renamed: 40474_mask_corrected.png → 40474_mask.png
# Removed: 40475_mask.png
# Renamed: 40475_mask_corrected.png → 40475_mask.png
# Removed: 40476_mask.png
# Renamed: 40476_mask_corrected.png → 40476_mask.png
# Removed: 40477_mask.png
# Renamed: 40477_mask_corrected.png → 40477_mask.png
# Removed: 40478_mask.png
# Renamed: 40478_mask_corrected.png → 40478_mask.png
# Removed: 40479_mask.png
# Renamed: 40479_mask_corrected.png → 40479_mask.png
# Removed: 40480_mask.png
# Renamed: 40480_mask_corrected.png → 40480_mask.png
# Removed: 40481_mask.png
# Renamed: 40481_mask_corrected.png → 40481_mask.png
# Removed: 40482_mask.png
# Renamed: 40482_mask_corrected.png → 40482_mask.png
# Removed: 40483_mask.png
# Renamed: 40483_mask_corrected.png → 40483_mask.png
# Removed: 40484_mask.png
# Renamed: 40484_mask_corrected.png → 40484_mask.png
# Removed: 40485_mask.png
# Renamed: 40485_mask_corrected.png → 40485_mask.png
# Removed: 40486_mask.png
# Renamed: 40486_mask_corrected.png → 40486_mask.png
# Removed: 40487_mask.png
# Renamed: 40487_mask_corrected.png → 40487_mask.png
# Removed: 40488_mask.png
# Renamed: 40488_mask_corrected.png → 40488_mask.png
# Removed: 40489_mask.png
# Renamed: 40489_mask_corrected.png → 40489_mask.png
# Removed: 40490_mask.png
# Renamed: 40490_mask_corrected.png → 40490_mask.png
# Removed: 40491_mask.png
# Renamed: 40491_mask_corrected.png → 40491_mask.png
# Removed: 40492_mask.png
# Renamed: 40492_mask_corrected.png → 40492_mask.png
# Removed: 40493_mask.png
# Renamed: 40493_mask_corrected.png → 40493_mask.png
# Removed: 40494_mask.png
# Renamed: 40494_mask_corrected.png → 40494_mask.png
# Removed: 40495_mask.png
# Renamed: 40495_mask_corrected.png → 40495_mask.png
# Removed: 40496_mask.png
# Renamed: 40496_mask_corrected.png → 40496_mask.png
# Removed: 40497_mask.png
# Renamed: 40497_mask_corrected.png → 40497_mask.png
# Removed: 40498_mask.png
# Renamed: 40498_mask_corrected.png → 40498_mask.png
# Removed: 40499_mask.png
# Renamed: 40499_mask_corrected.png → 40499_mask.png
# Removed: 40500_mask.png
# Renamed: 40500_mask_corrected.png → 40500_mask.png
# Removed: 40501_mask.png
# Renamed: 40501_mask_corrected.png → 40501_mask.png
# Removed: 40502_mask.png
# Renamed: 40502_mask_corrected.png → 40502_mask.png
# Removed: 40503_mask.png
# Renamed: 40503_mask_corrected.png → 40503_mask.png
# Removed: 40504_mask.png
# Renamed: 40504_mask_corrected.png → 40504_mask.png
# Removed: 40505_mask.png
# Renamed: 40505_mask_corrected.png → 40505_mask.png
# Removed: 40506_mask.png
# Renamed: 40506_mask_corrected.png → 40506_mask.png
# Removed: 40507_mask.png
# Renamed: 40507_mask_corrected.png → 40507_mask.png
# Removed: 40508_mask.png
# Renamed: 40508_mask_corrected.png → 40508_mask.png
# Removed: 40509_mask.png
# Renamed: 40509_mask_corrected.png → 40509_mask.png
# Removed: 40510_mask.png
# Renamed: 40510_mask_corrected.png → 40510_mask.png
# Removed: 40511_mask.png
# Renamed: 40511_mask_corrected.png → 40511_mask.png
# Removed: 40512_mask.png
# Renamed: 40512_mask_corrected.png → 40512_mask.png
# Removed: 40513_mask.png
# Renamed: 40513_mask_corrected.png → 40513_mask.png
# Removed: 40514_mask.png
# Renamed: 40514_mask_corrected.png → 40514_mask.png
# Removed: 40515_mask.png
# Renamed: 40515_mask_corrected.png → 40515_mask.png
# Removed: 40516_mask.png
# Renamed: 40516_mask_corrected.png → 40516_mask.png
# Removed: 40517_mask.png
# Renamed: 40517_mask_corrected.png → 40517_mask.png
# Removed: 40518_mask.png
# Renamed: 40518_mask_corrected.png → 40518_mask.png
# Removed: 40519_mask.png
# Renamed: 40519_mask_corrected.png → 40519_mask.png
# Removed: 40520_mask.png
# Renamed: 40520_mask_corrected.png → 40520_mask.png
# Removed: 40521_mask.png
# Renamed: 40521_mask_corrected.png → 40521_mask.png
# Removed: 40522_mask.png
# Renamed: 40522_mask_corrected.png → 40522_mask.png
# Removed: 40523_mask.png
# Renamed: 40523_mask_corrected.png → 40523_mask.png
# Removed: 40524_mask.png
# Renamed: 40524_mask_corrected.png → 40524_mask.png
# Removed: 40525_mask.png
# Renamed: 40525_mask_corrected.png → 40525_mask.png
# Removed: 40526_mask.png
# Renamed: 40526_mask_corrected.png → 40526_mask.png
# Removed: 40527_mask.png
# Renamed: 40527_mask_corrected.png → 40527_mask.png
# Removed: 40528_mask.png
# Renamed: 40528_mask_corrected.png → 40528_mask.png
# Removed: 40529_mask.png
# Renamed: 40529_mask_corrected.png → 40529_mask.png
# Removed: 40530_mask.png
# Renamed: 40530_mask_corrected.png → 40530_mask.png
# Removed: 40531_mask.png
# Renamed: 40531_mask_corrected.png → 40531_mask.png
# Removed: 40532_mask.png
# Renamed: 40532_mask_corrected.png → 40532_mask.png
# Removed: 40533_mask.png
# Renamed: 40533_mask_corrected.png → 40533_mask.png
# Removed: 40534_mask.png
# Renamed: 40534_mask_corrected.png → 40534_mask.png
# Removed: 40535_mask.png
# Renamed: 40535_mask_corrected.png → 40535_mask.png
# Removed: 40536_mask.png
# Renamed: 40536_mask_corrected.png → 40536_mask.png
# Removed: 40537_mask.png
# Renamed: 40537_mask_corrected.png → 40537_mask.png
# Removed: 40538_mask.png
# Renamed: 40538_mask_corrected.png → 40538_mask.png
# Removed: 40539_mask.png
# Renamed: 40539_mask_corrected.png → 40539_mask.png
# Removed: 40540_mask.png
# Renamed: 40540_mask_corrected.png → 40540_mask.png
# Removed: 40541_mask.png
# Renamed: 40541_mask_corrected.png → 40541_mask.png
# Removed: 40542_mask.png
# Renamed: 40542_mask_corrected.png → 40542_mask.png
# Removed: 40543_mask.png
# Renamed: 40543_mask_corrected.png → 40543_mask.png
# Removed: 40544_mask.png
# Renamed: 40544_mask_corrected.png → 40544_mask.png
# Removed: 40545_mask.png
# Renamed: 40545_mask_corrected.png → 40545_mask.png
# Removed: 40546_mask.png
# Renamed: 40546_mask_corrected.png → 40546_mask.png
# Removed: 40547_mask.png
# Renamed: 40547_mask_corrected.png → 40547_mask.png
# Removed: 40548_mask.png
# Renamed: 40548_mask_corrected.png → 40548_mask.png
# Removed: 40549_mask.png
# Renamed: 40549_mask_corrected.png → 40549_mask.png
# Removed: 40550_mask.png
# Renamed: 40550_mask_corrected.png → 40550_mask.png
# Removed: 40551_mask.png
# Renamed: 40551_mask_corrected.png → 40551_mask.png
# Removed: 40552_mask.png
# Renamed: 40552_mask_corrected.png → 40552_mask.png
# Removed: 40553_mask.png
# Renamed: 40553_mask_corrected.png → 40553_mask.png
# Removed: 40554_mask.png
# Renamed: 40554_mask_corrected.png → 40554_mask.png
# Removed: 40555_mask.png
# Renamed: 40555_mask_corrected.png → 40555_mask.png
# Removed: 40556_mask.png
# Renamed: 40556_mask_corrected.png → 40556_mask.png
# Removed: 40557_mask.png
# Renamed: 40557_mask_corrected.png → 40557_mask.png
# Removed: 40558_mask.png
# Renamed: 40558_mask_corrected.png → 40558_mask.png
# Removed: 40559_mask.png
# Renamed: 40559_mask_corrected.png → 40559_mask.png
# Removed: 40560_mask.png
# Renamed: 40560_mask_corrected.png → 40560_mask.png
# Removed: 40561_mask.png
# Renamed: 40561_mask_corrected.png → 40561_mask.png
# Removed: 40562_mask.png
# Renamed: 40562_mask_corrected.png → 40562_mask.png
# Removed: 40563_mask.png
# Renamed: 40563_mask_corrected.png → 40563_mask.png
# Removed: 40564_mask.png
# Renamed: 40564_mask_corrected.png → 40564_mask.png
# Removed: 40565_mask.png
# Renamed: 40565_mask_corrected.png → 40565_mask.png
# Removed: 40566_mask.png
# Renamed: 40566_mask_corrected.png → 40566_mask.png
# Removed: 40567_mask.png
# Renamed: 40567_mask_corrected.png → 40567_mask.png
# Removed: 40568_mask.png
# Renamed: 40568_mask_corrected.png → 40568_mask.png
# Removed: 40569_mask.png
# Renamed: 40569_mask_corrected.png → 40569_mask.png
# Removed: 40570_mask.png
# Renamed: 40570_mask_corrected.png → 40570_mask.png
# Removed: 40571_mask.png
# Renamed: 40571_mask_corrected.png → 40571_mask.png
# Removed: 40572_mask.png
# Renamed: 40572_mask_corrected.png → 40572_mask.png
# Removed: 40573_mask.png
# Renamed: 40573_mask_corrected.png → 40573_mask.png
# Removed: 40574_mask.png
# Renamed: 40574_mask_corrected.png → 40574_mask.png
# Removed: 40575_mask.png
# Renamed: 40575_mask_corrected.png → 40575_mask.png
# Removed: 40576_mask.png
# Renamed: 40576_mask_corrected.png → 40576_mask.png
# Removed: 40577_mask.png
# Renamed: 40577_mask_corrected.png → 40577_mask.png
# Removed: 40578_mask.png
# Renamed: 40578_mask_corrected.png → 40578_mask.png
# Removed: 40579_mask.png
# Renamed: 40579_mask_corrected.png → 40579_mask.png
# Removed: 40580_mask.png
# Renamed: 40580_mask_corrected.png → 40580_mask.png
# Removed: 40581_mask.png
# Renamed: 40581_mask_corrected.png → 40581_mask.png
# Removed: 40582_mask.png
# Renamed: 40582_mask_corrected.png → 40582_mask.png
# Removed: 40583_mask.png
# Renamed: 40583_mask_corrected.png → 40583_mask.png
# Removed: 40584_mask.png
# Renamed: 40584_mask_corrected.png → 40584_mask.png
# Removed: 40585_mask.png
# Renamed: 40585_mask_corrected.png → 40585_mask.png
# Removed: 40586_mask.png
# Renamed: 40586_mask_corrected.png → 40586_mask.png
# Removed: 40587_mask.png
# Renamed: 40587_mask_corrected.png → 40587_mask.png
# Removed: 40588_mask.png
# Renamed: 40588_mask_corrected.png → 40588_mask.png
# Removed: 40589_mask.png
# Renamed: 40589_mask_corrected.png → 40589_mask.png
# Removed: 40590_mask.png
# Renamed: 40590_mask_corrected.png → 40590_mask.png
# Removed: 40591_mask.png
# Renamed: 40591_mask_corrected.png → 40591_mask.png
# Removed: 40592_mask.png
# Renamed: 40592_mask_corrected.png → 40592_mask.png
# Removed: 40593_mask.png
# Renamed: 40593_mask_corrected.png → 40593_mask.png
# Removed: 40594_mask.png
# Renamed: 40594_mask_corrected.png → 40594_mask.png
# Removed: 40595_mask.png
# Renamed: 40595_mask_corrected.png → 40595_mask.png
# Removed: 40596_mask.png
# Renamed: 40596_mask_corrected.png → 40596_mask.png
# Removed: 40597_mask.png
# Renamed: 40597_mask_corrected.png → 40597_mask.png
# Removed: 40598_mask.png
# Renamed: 40598_mask_corrected.png → 40598_mask.png
# Removed: 40599_mask.png
# Renamed: 40599_mask_corrected.png → 40599_mask.png
# Removed: 40600_mask.png
# Renamed: 40600_mask_corrected.png → 40600_mask.png
# Removed: 40601_mask.png
# Renamed: 40601_mask_corrected.png → 40601_mask.png
# Removed: 40602_mask.png
# Renamed: 40602_mask_corrected.png → 40602_mask.png
# Removed: 40603_mask.png
# Renamed: 40603_mask_corrected.png → 40603_mask.png
# Removed: 40604_mask.png
# Renamed: 40604_mask_corrected.png → 40604_mask.png
# Removed: 40605_mask.png
# Renamed: 40605_mask_corrected.png → 40605_mask.png
# Removed: 40606_mask.png
# Renamed: 40606_mask_corrected.png → 40606_mask.png
# Removed: 40607_mask.png
# Renamed: 40607_mask_corrected.png → 40607_mask.png
# Removed: 40608_mask.png
# Renamed: 40608_mask_corrected.png → 40608_mask.png
# Removed: 40609_mask.png
# Renamed: 40609_mask_corrected.png → 40609_mask.png
# Removed: 40610_mask.png
# Renamed: 40610_mask_corrected.png → 40610_mask.png
# Removed: 40611_mask.png
# Renamed: 40611_mask_corrected.png → 40611_mask.png
# Removed: 40612_mask.png
# Renamed: 40612_mask_corrected.png → 40612_mask.png
# Removed: 40613_mask.png
# Renamed: 40613_mask_corrected.png → 40613_mask.png
# Removed: 40614_mask.png
# Renamed: 40614_mask_corrected.png → 40614_mask.png
# Removed: 40615_mask.png
# Renamed: 40615_mask_corrected.png → 40615_mask.png
# Removed: 40616_mask.png
# Renamed: 40616_mask_corrected.png → 40616_mask.png
# Removed: 40617_mask.png
# Renamed: 40617_mask_corrected.png → 40617_mask.png
# Removed: 40618_mask.png
# Renamed: 40618_mask_corrected.png → 40618_mask.png
# Removed: 40619_mask.png
# Renamed: 40619_mask_corrected.png → 40619_mask.png
# Removed: 40620_mask.png
# Renamed: 40620_mask_corrected.png → 40620_mask.png
# Removed: 40621_mask.png
# Renamed: 40621_mask_corrected.png → 40621_mask.png
# Removed: 40622_mask.png
# Renamed: 40622_mask_corrected.png → 40622_mask.png
# Removed: 40623_mask.png
# Renamed: 40623_mask_corrected.png → 40623_mask.png
# Removed: 40624_mask.png
# Renamed: 40624_mask_corrected.png → 40624_mask.png
# Removed: 40625_mask.png
# Renamed: 40625_mask_corrected.png → 40625_mask.png
# Removed: 40626_mask.png
# Renamed: 40626_mask_corrected.png → 40626_mask.png
# Removed: 40627_mask.png
# Renamed: 40627_mask_corrected.png → 40627_mask.png
# Removed: 40628_mask.png
# Renamed: 40628_mask_corrected.png → 40628_mask.png
# Removed: 40629_mask.png
# Renamed: 40629_mask_corrected.png → 40629_mask.png
# Removed: 40630_mask.png
# Renamed: 40630_mask_corrected.png → 40630_mask.png
# Removed: 40631_mask.png
# Renamed: 40631_mask_corrected.png → 40631_mask.png
# Removed: 40632_mask.png
# Renamed: 40632_mask_corrected.png → 40632_mask.png
# Removed: 40633_mask.png
# Renamed: 40633_mask_corrected.png → 40633_mask.png
# Removed: 40634_mask.png
# Renamed: 40634_mask_corrected.png → 40634_mask.png
# Removed: 40635_mask.png
# Renamed: 40635_mask_corrected.png → 40635_mask.png
# Removed: 40636_mask.png
# Renamed: 40636_mask_corrected.png → 40636_mask.png
# Removed: 40637_mask.png
# Renamed: 40637_mask_corrected.png → 40637_mask.png
# Removed: 40638_mask.png
# Renamed: 40638_mask_corrected.png → 40638_mask.png
# Removed: 40639_mask.png
# Renamed: 40639_mask_corrected.png → 40639_mask.png
# Removed: 40640_mask.png
# Renamed: 40640_mask_corrected.png → 40640_mask.png
# ...
# Removed: 65538_mask.png
# Renamed: 65538_mask_corrected.png → 65538_mask.png
# Removed: 65539_mask.png
# Renamed: 65539_mask_corrected.png → 65539_mask.png
# Removed: 65540_mask.png
# Renamed: 65540_mask_corrected.png → 65540_mask.png
# Removed: 65541_mask.png
# Renamed: 65541_mask_corrected.png → 65541_mask.png
# Removed: 65542_mask.png
# Renamed: 65542_mask_corrected.png → 65542_mask.png
# Removed: 65543_mask.png
# Renamed: 65543_mask_corrected.png → 65543_mask.png
# Removed: 65544_mask.png
# Renamed: 65544_mask_corrected.png → 65544_mask.png
# Removed: 65545_mask.png
# Renamed: 65545_mask_corrected.png → 65545_mask.png
# Removed: 65546_mask.png
# Renamed: 65546_mask_corrected.png → 65546_mask.png
# Removed: 65547_mask.png
# Renamed: 65547_mask_corrected.png → 65547_mask.png
# Removed: 65548_mask.png
# Renamed: 65548_mask_corrected.png → 65548_mask.png
# Removed: 65549_mask.png
# Renamed: 65549_mask_corrected.png → 65549_mask.png
# Removed: 65550_mask.png
# Renamed: 65550_mask_corrected.png → 65550_mask.png
# Removed: 65551_mask.png
# Renamed: 65551_mask_corrected.png → 65551_mask.png
# Removed: 65552_mask.png
# Renamed: 65552_mask_corrected.png → 65552_mask.png
# Removed: 65553_mask.png
# Renamed: 65553_mask_corrected.png → 65553_mask.png
# Removed: 65554_mask.png
# Renamed: 65554_mask_corrected.png → 65554_mask.png
# Removed: 65555_mask.png
# Renamed: 65555_mask_corrected.png → 65555_mask.png
# Removed: 65556_mask.png
# Renamed: 65556_mask_corrected.png → 65556_mask.png
# Removed: 65557_mask.png
# Renamed: 65557_mask_corrected.png → 65557_mask.png
# Removed: 65558_mask.png
# Renamed: 65558_mask_corrected.png → 65558_mask.png
# Removed: 65559_mask.png
# Renamed: 65559_mask_corrected.png → 65559_mask.png
# Removed: 65560_mask.png
# Renamed: 65560_mask_corrected.png → 65560_mask.png
# Removed: 65561_mask.png
# Renamed: 65561_mask_corrected.png → 65561_mask.png
# Removed: 65562_mask.png
# Renamed: 65562_mask_corrected.png → 65562_mask.png
# Removed: 65563_mask.png
# Renamed: 65563_mask_corrected.png → 65563_mask.png
# Removed: 65564_mask.png
# Renamed: 65564_mask_corrected.png → 65564_mask.png
# Removed: 65565_mask.png
# Renamed: 65565_mask_corrected.png → 65565_mask.png
# Removed: 65566_mask.png
# Renamed: 65566_mask_corrected.png → 65566_mask.png
# Removed: 65567_mask.png
# Renamed: 65567_mask_corrected.png → 65567_mask.png
# Removed: 65568_mask.png
# Renamed: 65568_mask_corrected.png → 65568_mask.png
# Removed: 65569_mask.png
# Renamed: 65569_mask_corrected.png → 65569_mask.png
# Removed: 65570_mask.png
# Renamed: 65570_mask_corrected.png → 65570_mask.png
# Removed: 65571_mask.png
# Renamed: 65571_mask_corrected.png → 65571_mask.png
# Removed: 65572_mask.png
# Renamed: 65572_mask_corrected.png → 65572_mask.png
# Removed: 65573_mask.png
# Renamed: 65573_mask_corrected.png → 65573_mask.png
# Removed: 65574_mask.png
# Renamed: 65574_mask_corrected.png → 65574_mask.png
# Removed: 65575_mask.png
# Renamed: 65575_mask_corrected.png → 65575_mask.png
# Removed: 65576_mask.png
# Renamed: 65576_mask_corrected.png → 65576_mask.png
# Removed: 65577_mask.png
# Renamed: 65577_mask_corrected.png → 65577_mask.png
# Removed: 65578_mask.png
# Renamed: 65578_mask_corrected.png → 65578_mask.png
# Removed: 65579_mask.png
# Renamed: 65579_mask_corrected.png → 65579_mask.png
# Removed: 65580_mask.png
# Renamed: 65580_mask_corrected.png → 65580_mask.png
# Removed: 65581_mask.png
# Renamed: 65581_mask_corrected.png → 65581_mask.png
# Removed: 65582_mask.png
# Renamed: 65582_mask_corrected.png → 65582_mask.png
# Removed: 65583_mask.png
# Renamed: 65583_mask_corrected.png → 65583_mask.png
# Removed: 65584_mask.png
# Renamed: 65584_mask_corrected.png → 65584_mask.png
# Removed: 65585_mask.png
# Renamed: 65585_mask_corrected.png → 65585_mask.png
# Removed: 65586_mask.png
# Renamed: 65586_mask_corrected.png → 65586_mask.png
# Removed: 65587_mask.png
# Renamed: 65587_mask_corrected.png → 65587_mask.png
# Removed: 65588_mask.png
# Renamed: 65588_mask_corrected.png → 65588_mask.png
# Removed: 65589_mask.png
# Renamed: 65589_mask_corrected.png → 65589_mask.png
# Removed: 65590_mask.png
# Renamed: 65590_mask_corrected.png → 65590_mask.png
# Removed: 65591_mask.png
# Renamed: 65591_mask_corrected.png → 65591_mask.png
# Removed: 65592_mask.png
# Renamed: 65592_mask_corrected.png → 65592_mask.png
# Removed: 65593_mask.png
# Renamed: 65593_mask_corrected.png → 65593_mask.png
# Removed: 65594_mask.png
# Renamed: 65594_mask_corrected.png → 65594_mask.png
# Removed: 65595_mask.png
# Renamed: 65595_mask_corrected.png → 65595_mask.png
# Removed: 65596_mask.png
# Renamed: 65596_mask_corrected.png → 65596_mask.png
# Removed: 65597_mask.png
# Renamed: 65597_mask_corrected.png → 65597_mask.png
# Removed: 65598_mask.png
# Renamed: 65598_mask_corrected.png → 65598_mask.png
# Removed: 65599_mask.png
# Renamed: 65599_mask_corrected.png → 65599_mask.png
# Removed: 65600_mask.png
# Renamed: 65600_mask_corrected.png → 65600_mask.png
# Removed: 65601_mask.png
# Renamed: 65601_mask_corrected.png → 65601_mask.png
# Removed: 65602_mask.png
# Renamed: 65602_mask_corrected.png → 65602_mask.png
# Removed: 65603_mask.png
# Renamed: 65603_mask_corrected.png → 65603_mask.png
# Removed: 65604_mask.png
# Renamed: 65604_mask_corrected.png → 65604_mask.png
# Removed: 65605_mask.png
# Renamed: 65605_mask_corrected.png → 65605_mask.png
# Removed: 65606_mask.png
# Renamed: 65606_mask_corrected.png → 65606_mask.png
# Removed: 65607_mask.png
# Renamed: 65607_mask_corrected.png → 65607_mask.png
# Removed: 65608_mask.png
# Renamed: 65608_mask_corrected.png → 65608_mask.png
# Removed: 65609_mask.png
# Renamed: 65609_mask_corrected.png → 65609_mask.png
# Removed: 65610_mask.png
# Renamed: 65610_mask_corrected.png → 65610_mask.png
# Removed: 65611_mask.png
# Renamed: 65611_mask_corrected.png → 65611_mask.png
# Removed: 65612_mask.png
# Renamed: 65612_mask_corrected.png → 65612_mask.png
# Removed: 65613_mask.png
# Renamed: 65613_mask_corrected.png → 65613_mask.png
# Removed: 65614_mask.png
# Renamed: 65614_mask_corrected.png → 65614_mask.png
# Removed: 65615_mask.png
# Renamed: 65615_mask_corrected.png → 65615_mask.png
# Removed: 65616_mask.png
# Renamed: 65616_mask_corrected.png → 65616_mask.png
# Removed: 65617_mask.png
# Renamed: 65617_mask_corrected.png → 65617_mask.png
# Removed: 65618_mask.png
# Renamed: 65618_mask_corrected.png → 65618_mask.png
# Removed: 65619_mask.png
# Renamed: 65619_mask_corrected.png → 65619_mask.png
# Removed: 65620_mask.png
# Renamed: 65620_mask_corrected.png → 65620_mask.png
# Removed: 65621_mask.png
# Renamed: 65621_mask_corrected.png → 65621_mask.png
# Removed: 65622_mask.png
# Renamed: 65622_mask_corrected.png → 65622_mask.png
# Removed: 65623_mask.png
# Renamed: 65623_mask_corrected.png → 65623_mask.png
# Removed: 65624_mask.png
# Renamed: 65624_mask_corrected.png → 65624_mask.png
# Removed: 65625_mask.png
# Renamed: 65625_mask_corrected.png → 65625_mask.png
# Removed: 65626_mask.png
# Renamed: 65626_mask_corrected.png → 65626_mask.png
# Removed: 65627_mask.png
# Renamed: 65627_mask_corrected.png → 65627_mask.png
# Removed: 65628_mask.png
# Renamed: 65628_mask_corrected.png → 65628_mask.png
# Removed: 65629_mask.png
# Renamed: 65629_mask_corrected.png → 65629_mask.png
# Removed: 65630_mask.png
# Renamed: 65630_mask_corrected.png → 65630_mask.png
# Removed: 65631_mask.png
# Renamed: 65631_mask_corrected.png → 65631_mask.png
# Removed: 65632_mask.png
# Renamed: 65632_mask_corrected.png → 65632_mask.png
# Removed: 65633_mask.png
# Renamed: 65633_mask_corrected.png → 65633_mask.png
# Removed: 65634_mask.png
# Renamed: 65634_mask_corrected.png → 65634_mask.png
# Removed: 65635_mask.png
# Renamed: 65635_mask_corrected.png → 65635_mask.png
# Removed: 65636_mask.png
# Renamed: 65636_mask_corrected.png → 65636_mask.png
# Removed: 65637_mask.png
# Renamed: 65637_mask_corrected.png → 65637_mask.png
# Removed: 65638_mask.png
# Renamed: 65638_mask_corrected.png → 65638_mask.png
# Removed: 65639_mask.png
# Renamed: 65639_mask_corrected.png → 65639_mask.png
# Removed: 65640_mask.png
# Renamed: 65640_mask_corrected.png → 65640_mask.png
# Removed: 65641_mask.png
# Renamed: 65641_mask_corrected.png → 65641_mask.png
# Removed: 65642_mask.png
# Renamed: 65642_mask_corrected.png → 65642_mask.png
# Removed: 65643_mask.png
# Renamed: 65643_mask_corrected.png → 65643_mask.png
# Removed: 65644_mask.png
# Renamed: 65644_mask_corrected.png → 65644_mask.png
# Removed: 65645_mask.png
# Renamed: 65645_mask_corrected.png → 65645_mask.png
# Removed: 65646_mask.png
# Renamed: 65646_mask_corrected.png → 65646_mask.png
# Removed: 65647_mask.png
# Renamed: 65647_mask_corrected.png → 65647_mask.png
# Removed: 65648_mask.png
# Renamed: 65648_mask_corrected.png → 65648_mask.png
# Removed: 65649_mask.png
# Renamed: 65649_mask_corrected.png → 65649_mask.png
# Removed: 65650_mask.png
# Renamed: 65650_mask_corrected.png → 65650_mask.png
# Removed: 65651_mask.png
# Renamed: 65651_mask_corrected.png → 65651_mask.png
# Removed: 65652_mask.png
# Renamed: 65652_mask_corrected.png → 65652_mask.png
# Removed: 65653_mask.png
# Renamed: 65653_mask_corrected.png → 65653_mask.png
# Removed: 65654_mask.png
# Renamed: 65654_mask_corrected.png → 65654_mask.png
# Removed: 65655_mask.png
# Renamed: 65655_mask_corrected.png → 65655_mask.png
# Removed: 65656_mask.png
# Renamed: 65656_mask_corrected.png → 65656_mask.png
# Removed: 65657_mask.png
# Renamed: 65657_mask_corrected.png → 65657_mask.png
# Removed: 65658_mask.png
# Renamed: 65658_mask_corrected.png → 65658_mask.png
# Removed: 65659_mask.png
# Renamed: 65659_mask_corrected.png → 65659_mask.png
# Removed: 65660_mask.png
# Renamed: 65660_mask_corrected.png → 65660_mask.png
# Removed: 65661_mask.png
# Renamed: 65661_mask_corrected.png → 65661_mask.png
# Removed: 65662_mask.png
# Renamed: 65662_mask_corrected.png → 65662_mask.png
# Removed: 65663_mask.png
# Renamed: 65663_mask_corrected.png → 65663_mask.png
# Removed: 65664_mask.png
# Renamed: 65664_mask_corrected.png → 65664_mask.png
# Removed: 65665_mask.png
# Renamed: 65665_mask_corrected.png → 65665_mask.png
# Removed: 65666_mask.png
# Renamed: 65666_mask_corrected.png → 65666_mask.png
# Removed: 65667_mask.png
# Renamed: 65667_mask_corrected.png → 65667_mask.png
# Removed: 65668_mask.png
# Renamed: 65668_mask_corrected.png → 65668_mask.png
# Removed: 65669_mask.png
# Renamed: 65669_mask_corrected.png → 65669_mask.png
# Removed: 65670_mask.png
# Renamed: 65670_mask_corrected.png → 65670_mask.png
# Removed: 65671_mask.png
# Renamed: 65671_mask_corrected.png → 65671_mask.png
# Removed: 65672_mask.png
# Renamed: 65672_mask_corrected.png → 65672_mask.png
# Removed: 65673_mask.png
# Renamed: 65673_mask_corrected.png → 65673_mask.png
# Removed: 65674_mask.png
# Renamed: 65674_mask_corrected.png → 65674_mask.png
# Removed: 65675_mask.png
# Renamed: 65675_mask_corrected.png → 65675_mask.png
# Removed: 65676_mask.png
# Renamed: 65676_mask_corrected.png → 65676_mask.png
# Removed: 65677_mask.png
# Renamed: 65677_mask_corrected.png → 65677_mask.png
# Removed: 65678_mask.png
# Renamed: 65678_mask_corrected.png → 65678_mask.png
# Removed: 65679_mask.png
# Renamed: 65679_mask_corrected.png → 65679_mask.png
# Removed: 65680_mask.png
# Renamed: 65680_mask_corrected.png → 65680_mask.png
# Removed: 65681_mask.png
# Renamed: 65681_mask_corrected.png → 65681_mask.png
# Removed: 65682_mask.png
# Renamed: 65682_mask_corrected.png → 65682_mask.png
# Removed: 65683_mask.png
# Renamed: 65683_mask_corrected.png → 65683_mask.png
# Removed: 65684_mask.png
# Renamed: 65684_mask_corrected.png → 65684_mask.png
# Removed: 65685_mask.png
# Renamed: 65685_mask_corrected.png → 65685_mask.png
# Removed: 65686_mask.png
# Renamed: 65686_mask_corrected.png → 65686_mask.png
# Removed: 65687_mask.png
# Renamed: 65687_mask_corrected.png → 65687_mask.png
# Removed: 65688_mask.png
# Renamed: 65688_mask_corrected.png → 65688_mask.png
# Removed: 65689_mask.png
# Renamed: 65689_mask_corrected.png → 65689_mask.png
# Removed: 65690_mask.png
# Renamed: 65690_mask_corrected.png → 65690_mask.png
# Removed: 65691_mask.png
# Renamed: 65691_mask_corrected.png → 65691_mask.png
# Removed: 65692_mask.png
# Renamed: 65692_mask_corrected.png → 65692_mask.png
# Removed: 65693_mask.png
# Renamed: 65693_mask_corrected.png → 65693_mask.png
# Removed: 65694_mask.png
# Renamed: 65694_mask_corrected.png → 65694_mask.png
# Removed: 65695_mask.png
# Renamed: 65695_mask_corrected.png → 65695_mask.png
# Removed: 65696_mask.png
# Renamed: 65696_mask_corrected.png → 65696_mask.png
# Removed: 65697_mask.png
# Renamed: 65697_mask_corrected.png → 65697_mask.png
# Removed: 65698_mask.png
# Renamed: 65698_mask_corrected.png → 65698_mask.png
# Removed: 65699_mask.png
# Renamed: 65699_mask_corrected.png → 65699_mask.png
# Removed: 65700_mask.png
# Renamed: 65700_mask_corrected.png → 65700_mask.png
# Removed: 65701_mask.png
# Renamed: 65701_mask_corrected.png → 65701_mask.png
# Removed: 65702_mask.png
# Renamed: 65702_mask_corrected.png → 65702_mask.png
# Removed: 65703_mask.png
# Renamed: 65703_mask_corrected.png → 65703_mask.png
# Removed: 65704_mask.png
# Renamed: 65704_mask_corrected.png → 65704_mask.png
# Removed: 65705_mask.png
# Renamed: 65705_mask_corrected.png → 65705_mask.png
# Removed: 65706_mask.png
# Renamed: 65706_mask_corrected.png → 65706_mask.png
# Removed: 65707_mask.png
# Renamed: 65707_mask_corrected.png → 65707_mask.png
# Removed: 65708_mask.png
# Renamed: 65708_mask_corrected.png → 65708_mask.png
# Removed: 65709_mask.png
# Renamed: 65709_mask_corrected.png → 65709_mask.png
# Removed: 65710_mask.png
# Renamed: 65710_mask_corrected.png → 65710_mask.png
# Removed: 65711_mask.png
# Renamed: 65711_mask_corrected.png → 65711_mask.png
# Removed: 65712_mask.png
# Renamed: 65712_mask_corrected.png → 65712_mask.png
# Removed: 65713_mask.png
# Renamed: 65713_mask_corrected.png → 65713_mask.png
# Removed: 65714_mask.png
# Renamed: 65714_mask_corrected.png → 65714_mask.png
# Removed: 65715_mask.png
# Renamed: 65715_mask_corrected.png → 65715_mask.png
# Removed: 65716_mask.png
# Renamed: 65716_mask_corrected.png → 65716_mask.png
# Removed: 65717_mask.png
# Renamed: 65717_mask_corrected.png → 65717_mask.png
# Removed: 65718_mask.png
# Renamed: 65718_mask_corrected.png → 65718_mask.png
# Removed: 65719_mask.png
# Renamed: 65719_mask_corrected.png → 65719_mask.png
# Removed: 65720_mask.png
# Renamed: 65720_mask_corrected.png → 65720_mask.png
# Removed: 65721_mask.png
# Renamed: 65721_mask_corrected.png → 65721_mask.png
# Removed: 65722_mask.png
# Renamed: 65722_mask_corrected.png → 65722_mask.png
# Removed: 65723_mask.png
# Renamed: 65723_mask_corrected.png → 65723_mask.png
# Removed: 65724_mask.png
# Renamed: 65724_mask_corrected.png → 65724_mask.png
# Removed: 65725_mask.png
# Renamed: 65725_mask_corrected.png → 65725_mask.png
# Removed: 65726_mask.png
# Renamed: 65726_mask_corrected.png → 65726_mask.png
# Removed: 65727_mask.png
# Renamed: 65727_mask_corrected.png → 65727_mask.png
# Removed: 65728_mask.png
# Renamed: 65728_mask_corrected.png → 65728_mask.png
# Removed: 65729_mask.png
# Renamed: 65729_mask_corrected.png → 65729_mask.png
# Removed: 65730_mask.png
# Renamed: 65730_mask_corrected.png → 65730_mask.png
# Removed: 65731_mask.png
# Renamed: 65731_mask_corrected.png → 65731_mask.png
# Removed: 65732_mask.png
# Renamed: 65732_mask_corrected.png → 65732_mask.png
# Removed: 65733_mask.png
# Renamed: 65733_mask_corrected.png → 65733_mask.png
# Removed: 65734_mask.png
# Renamed: 65734_mask_corrected.png → 65734_mask.png
# Removed: 65735_mask.png
# Renamed: 65735_mask_corrected.png → 65735_mask.png
# Removed: 65736_mask.png
# Renamed: 65736_mask_corrected.png → 65736_mask.png
# Removed: 65737_mask.png
# Renamed: 65737_mask_corrected.png → 65737_mask.png
# Removed: 65738_mask.png
# Renamed: 65738_mask_corrected.png → 65738_mask.png
# Removed: 65739_mask.png
# Renamed: 65739_mask_corrected.png → 65739_mask.png
# Removed: 65740_mask.png
# Renamed: 65740_mask_corrected.png → 65740_mask.png
# Removed: 65741_mask.png
# Renamed: 65741_mask_corrected.png → 65741_mask.png
# Removed: 65742_mask.png
# Renamed: 65742_mask_corrected.png → 65742_mask.png
# Removed: 65743_mask.png
# Renamed: 65743_mask_corrected.png → 65743_mask.png
# Removed: 65744_mask.png
# Renamed: 65744_mask_corrected.png → 65744_mask.png
# Removed: 65745_mask.png
# Renamed: 65745_mask_corrected.png → 65745_mask.png
# Removed: 65746_mask.png
# Renamed: 65746_mask_corrected.png → 65746_mask.png
# Removed: 65747_mask.png
# Renamed: 65747_mask_corrected.png → 65747_mask.png
# Removed: 65748_mask.png
# Renamed: 65748_mask_corrected.png → 65748_mask.png
# Removed: 65749_mask.png
# Renamed: 65749_mask_corrected.png → 65749_mask.png
# Removed: 65750_mask.png
# Renamed: 65750_mask_corrected.png → 65750_mask.png

# %%
import os
import re

def renumber_pairs_in_dir(folder, old_start=3001, new_start=1501,
                          rgb_suffix="_rgb.png", mask_suffix="_mask.png", dry_run=False):
    """
    Renames all paired files in a folder, shifting numeric prefixes.
    Example:
        03001_rgb.png -> 01501_rgb.png
        03001_mask.png -> 01501_mask.png

    Args:
        folder      : directory containing the files
        old_start   : first old number (e.g., 3001)
        new_start   : number to start from (e.g., 1501)
        rgb_suffix  : suffix pattern for RGB files
        mask_suffix : suffix pattern for MASK files
        dry_run     : if True, only prints what would happen (no renaming)
    """
    files = sorted(os.listdir(folder))
    pattern_rgb = re.compile(rf"^(\d+){re.escape(rgb_suffix)}$")
    pattern_mask = re.compile(rf"^(\d+){re.escape(mask_suffix)}$")
    
    # collect all unique numeric prefixes
    ids = set()
    for fname in files:
        m1 = pattern_rgb.match(fname)
        m2 = pattern_mask.match(fname)
        if m1:
            ids.add(int(m1.group(1)))
        elif m2:
            ids.add(int(m2.group(1)))

    if not ids:
        print("⚠️ No matching files found.")
        return
    
    ids = sorted(ids)
    offset = new_start - ids[0]
    print(f"Found {len(ids)} sequences. Renumbering {ids[0]}..{ids[-1]} → starts at {new_start}")
    print(f"Offset = {offset:+d}")

    renamed = 0
    for old_id in ids:
        new_id = old_id + offset
        for suffix in [rgb_suffix, mask_suffix]:
            old_name = f"{old_id:05d}{suffix}"
            new_name = f"{new_id:05d}{suffix}"
            old_path = os.path.join(folder, old_name)
            new_path = os.path.join(folder, new_name)
            if os.path.exists(old_path):
                if dry_run:
                    print(f"[DRY] {old_name} -> {new_name}")
                else:
                    os.rename(old_path, new_path)
                    renamed += 1
    if dry_run:
        print("✅ Dry run complete. Set dry_run=False to apply changes.")
    else:
        print(f"✅ Done. {renamed} files renamed.")

# Example usage:
# renumber_pairs_in_dir(r"D:\data\fehling_dataset\train", old_start=3001, new_start=1501, dry_run=True)

# %%
renumber_pairs_in_dir(r"C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\test_val_extension")
# Out:
# Found 2000 sequences. Renumbering 3001..5000 → starts at 1501
# Offset = -1500
# ✅ Done. 4000 files renamed.

# %%
# FIX MASKS (CREATE UNIFIED GLOTTAL COMPLEX)

import os
from glob import glob
from PIL import Image
import cv2
import numpy as np
from pathlib import Path

BG, GLOTTIS, RIGHT, LEFT = 0, 1, 2, 3

def _read_rgb(path):
    im_bgr = cv2.imread(path, cv2.IMREAD_COLOR)
    return cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB) if im_bgr is not None else None

def _read_mask(path):
    m = cv2.imread(path, cv2.IMREAD_UNCHANGED)
    if m.ndim == 3:
        m = cv2.cvtColor(m, cv2.COLOR_BGR2GRAY)
    return m.astype(np.uint8)

def _save_mask(path, mask):
    Path(os.path.dirname(path)).mkdir(parents=True, exist_ok=True)
    cv2.imwrite(path, mask.astype(np.uint8))

def _extract_scribbles(rgb):
    """Detect blue (→ RIGHT) and green (→ LEFT) scribble lines with strict tolerance."""
    bgr = cv2.cvtColor(rgb, cv2.COLOR_RGB2BGR)

    # blue (BGR ~ 255,0,0)
    lower_blue  = np.array([240, 0, 0])
    upper_blue  = np.array([255, 20, 20])
    blue_mask = cv2.inRange(bgr, lower_blue, upper_blue)

    # green (BGR ~ 0,255,0)
    lower_green = np.array([0, 240, 0])
    upper_green = np.array([20, 255, 20])
    green_mask = cv2.inRange(bgr, lower_green, upper_green)

    return (blue_mask>0).astype(np.uint8), (green_mask>0).astype(np.uint8)

def _fill_closed_contour(line_mask, min_area=30):
    """
    Given a binary scribble line (closed), return its filled interior.
    """
    if line_mask.sum() == 0:
        return np.zeros_like(line_mask, np.uint8)

    # Find contours and fill them
    cnts, _ = cv2.findContours(line_mask.astype(np.uint8),
                               cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    filled = np.zeros_like(line_mask, np.uint8)
    for c in cnts:
        if cv2.contourArea(c) >= min_area:
            cv2.drawContours(filled, [c], -1, 1, thickness=cv2.FILLED)
    return filled

def correct_folds_from_closed_contours(root_dir, target_dir):
    """
    Replace folds in *_mask.png with filled regions from closed blue/green scribbles.
    """
    os.makedirs(target_dir, exist_ok=True)
    rgb_paths = sorted(glob(os.path.join(root_dir, "*_rgb.png")))
    for rgb_path in rgb_paths:
        mask_path = rgb_path.replace("_rgb.png", "_mask.png")
        if not os.path.exists(mask_path):
            continue

        rgb   = _read_rgb(rgb_path)
        mask  = _read_mask(mask_path)
        gl    = (mask == GLOTTIS)

        # start fresh (remove folds)
        corrected = mask.copy()
        corrected[(mask == RIGHT) | (mask == LEFT)] = BG

        # scribbles
        blue_line, green_line = _extract_scribbles(rgb)

        # fill interiors of closed contours
        right_fill = _fill_closed_contour(blue_line)
        left_fill  = _fill_closed_contour(green_line)

        # apply them, restricted to non-glottis
        corrected[right_fill.astype(bool) & (~gl)] = RIGHT
        corrected[left_fill.astype(bool)  & (~gl)] = LEFT

        # restore glottis
        corrected[gl] = GLOTTIS

        out_path = os.path.join(
            target_dir,
            os.path.basename(mask_path).replace("_mask.png", "_mask_corrected.png")
        )
        _save_mask(out_path, corrected)

        print(f"✔ {os.path.basename(mask_path)} → {os.path.basename(out_path)} "
              f"(blue_px={int(blue_line.sum())}, green_px={int(green_line.sum())})")

def fix_masks_make_unified_complex(root_dir):
    """
    Walk all '*_mask.png' files under `root_dir` and fix the segmentation so that:
      1) There is exactly ONE unified folds–glottis complex (labels {1,2,3}).
         Any folds (2 or 3) outside this main complex are set to background (0).
         Glottis (1) is NEVER changed.
      2) No background (0) is allowed *inside* the complex:
         all background "holes" enclosed by {1,2,3} are reassigned to the nearest /
         most-adjacent fold (2 or 3). Glottis (1) remains untouched.

    Labels: 0=background, 1=glottis (GT, immutable), 2=right fold, 3=left fold.
    """
    try:
        from scipy.ndimage import (
            label as cc_label,
            binary_fill_holes,
            binary_dilation,
            generate_binary_structure,
            distance_transform_edt,
        )
        _use_scipy = True
    except Exception:
        # Minimal fallbacks using OpenCV if SciPy is unavailable
        import cv2
        _use_scipy = False

        def _cc_label(mask):
            # 8-connected components
            num, lab, stats, _ = cv2.connectedComponentsWithStats(
                mask.astype(np.uint8), connectivity=8
            )
            return lab, num - 1  # lab includes background=0

        def _binary_fill_holes(mask):
            # flood fill from 4 corners to get outside background; holes are the rest of bg
            h, w = mask.shape
            inv = (~mask).astype(np.uint8)  # 1 where background
            ff = inv.copy()
            mm = np.zeros((h + 2, w + 2), np.uint8)
            for seed in [(0, 0), (0, w - 1), (h - 1, 0), (h - 1, w - 1)]:
                cv2.floodFill(ff, mm.copy(), seedPoint=seed, newVal=2)
            outside = (ff == 2)
            holes = (~outside) & (~mask)
            filled = mask | holes
            return filled, holes

        def _binary_dilation(mask):
            k = np.ones((3, 3), np.uint8)
            return cv2.dilate(mask.astype(np.uint8), k, iterations=1).astype(bool)

        def _distance_transform(mask):
            # distance to True pixels
            import cv2
            inv = (~mask).astype(np.uint8)
            dist = cv2.distanceTransform(inv, cv2.DIST_L2, 3)
            return dist

    def _process_single(arr):
        """
        arr: (H,W) uint8 in {0,1,2,3}
        returns corrected arr
        """
        arr = arr.copy()

        glottis = (arr == 1)
        fold2 = (arr == 2)
        fold3 = (arr == 3)
        complex_mask = glottis | fold2 | fold3

        if _use_scipy:
            st = generate_binary_structure(2, 2)  # 8-connectivity
            cc, n = cc_label(complex_mask, st)
        else:
            cc, n = _cc_label(complex_mask)

        # ---- choose the main complex ----
        if n <= 1:
            main = complex_mask
        else:
            if glottis.any():
                # pick the component that overlaps the glottis the most
                ids, counts = np.unique(cc[glottis], return_counts=True)
                ids = ids[ids > 0]
                if len(ids):
                    main_id = ids[np.argmax(counts)]
                else:
                    # fallback: largest by area
                    areas = np.bincount(cc.ravel())
                    areas[0] = 0
                    main_id = np.argmax(areas)
            else:
                areas = np.bincount(cc.ravel())
                areas[0] = 0
                main_id = np.argmax(areas)
            main = (cc == main_id)

        # ---- remove stray folds outside the main complex (glottis never changed) ----
        outside_folds = (~main) & ((arr == 2) | (arr == 3))
        arr[outside_folds] = 0

        # recompute masks after cleanup
        fold2 = (arr == 2)
        fold3 = (arr == 3)
        complex_mask = glottis | fold2 | fold3

        # ---- fill background holes inside the complex (assign to fold 2 or 3) ----
        if _use_scipy:
            st = generate_binary_structure(2, 2)
            filled = binary_fill_holes(complex_mask, structure=st)
            holes = filled & (~complex_mask)  # background islands fully enclosed
        else:
            filled, holes = _binary_fill_holes(complex_mask)

        if holes.any():
            # label hole components
            if _use_scipy:
                h_lbl, h_num = cc_label(holes, st)
            else:
                h_lbl, h_num = _cc_label(holes)

            # Precompute distances for fallback
            if _use_scipy:
                dist2 = distance_transform_edt(~fold2) if fold2.any() else np.full(arr.shape, np.inf, dtype=np.float32)
                dist3 = distance_transform_edt(~fold3) if fold3.any() else np.full(arr.shape, np.inf, dtype=np.float32)
            else:
                dist2 = _distance_transform(fold2) if fold2.any() else np.full(arr.shape, np.inf, dtype=np.float32)
                dist3 = _distance_transform(fold3) if fold3.any() else np.full(arr.shape, np.inf, dtype=np.float32)

            for hid in range(1, h_num + 1):
                hm = (h_lbl == hid)

                # boundary of the hole (8-neighborhood)
                if _use_scipy:
                    bd = binary_dilation(hm, structure=st) & (~hm)
                else:
                    bd = _binary_dilation(hm) & (~hm)

                touch2 = int(np.count_nonzero(bd & (arr == 2)))
                touch3 = int(np.count_nonzero(bd & (arr == 3)))

                if touch2 == 0 and touch3 == 0:
                    # fallback: choose the closer fold by EDT
                    d2 = float(np.min(dist2[hm])) if np.isfinite(dist2).any() else np.inf
                    d3 = float(np.min(dist3[hm])) if np.isfinite(dist3).any() else np.inf
                    to_label = 2 if d2 <= d3 else 3
                else:
                    # choose the fold with stronger boundary contact (ties -> 2)
                    to_label = 2 if touch2 >= touch3 else 3

                arr[hm] = to_label  # never write 1 here (only background holes are filled)

        return arr

    mask_paths = glob(os.path.join(root_dir, "**", "*_mask.png"), recursive=True)
    print(f"🛠  Fixing {len(mask_paths)} masks under: {root_dir}")

    changed = 0
    for mp in mask_paths:
        try:
            lab = np.array(Image.open(mp).convert("L"), dtype=np.uint8)
            fixed = _process_single(lab)
            if not np.array_equal(lab, fixed):
                Image.fromarray(fixed, mode="L").save(mp)
                changed += 1
        except Exception as e:
            print(f"❌ Failed on {mp}: {e}")

    print(f"✅ Done. Updated {changed}/{len(mask_paths)} masks.")

# %%
def copy_nth_of_each_hundred(root_dir, target_dir, n=50, copy_mask=True, overwrite=False):
    """
    From a flat folder `root_dir` containing files like '10001_rgb.png' (and usually
    '10001_mask.png'), copy only those frames whose index is the n-th within each
    100-block (e.g., n=50 → 10050, 10150, 10250, ...). Files are copied to `target_dir`
    keeping the original filenames.

    Args:
        root_dir   : source folder with *_rgb.png (and *_mask.png)
        target_dir : destination folder (created if missing)
        n          : which index inside each 100 (0..99); default 50
        copy_mask  : also copy the corresponding *_mask.png if present
        overwrite  : if False and a file exists in target, it is skipped

    Returns:
        List of integer indices copied (e.g., [10050, 10150, ...]).
    """
    import os, re, shutil

    if not (0 <= int(n) <= 99):
        raise ValueError("n must be in [0, 99]")

    os.makedirs(target_dir, exist_ok=True)
    want = n % 100

    rgb_regex = re.compile(r"^(\d+)_rgb\.png$", re.IGNORECASE)

    # gather candidate *_rgb.png files and filter by modulo rule
    candidates = []
    for name in os.listdir(root_dir):
        m = rgb_regex.match(name)
        if not m:
            continue
        idx = int(m.group(1))
        if idx % 100 == want:
            candidates.append((idx, name))

    # sort by numeric index
    candidates.sort(key=lambda x: x[0])

    copied = []
    for idx, rgb_name in candidates:
        src_rgb = os.path.join(root_dir, rgb_name)
        dst_rgb = os.path.join(target_dir, rgb_name)

        # copy RGB (respect overwrite flag)
        if overwrite or not os.path.exists(dst_rgb):
            shutil.copy2(src_rgb, dst_rgb)

        if copy_mask:
            stem = rgb_name.replace("_rgb.png", "")
            # prefer *_mask.png; fall back to *_seg4.png or *_seg.png if needed
            mask_candidates = [
                f"{stem}_mask.png",
                f"{stem}_seg4.png",
                f"{stem}_seg.png",
            ]
            for mn in mask_candidates:
                src_m = os.path.join(root_dir, mn)
                if os.path.exists(src_m):
                    dst_m = os.path.join(target_dir, mn)
                    if overwrite or not os.path.exists(dst_m):
                        shutil.copy2(src_m, dst_m)
                    break  # stop at first existing mask variant

        copied.append(idx)

    print(f"✅ Copied {len(copied)} frames to '{target_dir}'. Example indices: {copied[:5]}{'...' if len(copied)>5 else ''}")
    return copied

# %%
source = r"C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension"
destination = r"C:\Users\olegp\miniconda3\envs\proj1\0_jupyter_notebook\data\train_extension\1"

copy_nth_of_each_hundred(source, destination)
